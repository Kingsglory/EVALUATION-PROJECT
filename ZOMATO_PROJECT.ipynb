# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\emeka\Downloads\zomato.csv", encoding="latin1")

df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()

#TO see the first 5 head and columns of the resturance table
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()

#The last part of the table
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
df.columns.to_list()

#List of all the columns
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
df.isnull().sum()
#To the see the presence of missing values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap='cool_r')

#To see the isnull in heatmap
# Out:
# <Axes: >

# %%
df.info()

#This shows 9550 entries, 21 columns, no missing values,dtype is object, float and int. the memory is 1.5+mb was used.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Restaurant ID
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: count, Length: 9551, dtype: int64
#
#
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64
#
#
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64
#
#
# City
# New Delhi           5473
# Gurgaon             1118
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#To check for categorical columns

categorical_colum=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_colum.append(i)
print("Categorical columns:",categorical_colum)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']
#
#
# Numerical columns: ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
df.set_index('Restaurant ID', inplace=True)

# %%
#MAKING THE RESTURANCE ID THE INDEX NAME

# %%
#DROPPING SOME COLUMNS THAT ARE NOT NECESSARY FOR ANALYSIS

df.drop(['Address','Country Code'],axis=1, inplace=True)

# %%
df
# Out:
#                         Restaurant Name              City  \
# Restaurant ID
# 6317637                Le Petit Souffle       Makati City
# 6304287                Izakaya Kikufuji       Makati City
# 6300002          Heat - Edsa Shangri-La  Mandaluyong City
# 6318506                            Ooma  Mandaluyong City
# 6314302                     Sambo Kojin  Mandaluyong City
# ...                                 ...               ...
# 5915730                    NamlÛ± Gurme         ÛÁstanbul
# 5908749                   Ceviz AÛôacÛ±         ÛÁstanbul
# 5915807                           Huqqa         ÛÁstanbul
# 5916112                    Aôôk Kahve         ÛÁstanbul
# 5927402        Walter's Coffee Roastery         ÛÁstanbul
#
#                                                  Locality  \
# Restaurant ID
# 6317637         Century City Mall, Poblacion, Makati City
# 6304287        Little Tokyo, Legaspi Village, Makati City
# 6300002        Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 18)

# %%
#To drop duplicate 

df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9551, 18)

# %%
df.head(4)
# Out:
#                       Restaurant Name              City  \
# Restaurant ID
# 6317637              Le Petit Souffle       Makati City
# 6304287              Izakaya Kikufuji       Makati City
# 6300002        Heat - Edsa Shangri-La  Mandaluyong City
# 6318506                          Ooma  Mandaluyong City
#
#                                                  Locality  \
# Restaurant ID
# 6317637         Century City Mall, Poblacion, Makati City
# 6304287        Little Tokyo, Legaspi Village, Makati City
# 6300002        Edsa Shangri-La, Ortigas, Mandaluyong City
# 6318506            SM Megamall, Ortigas, Mandaluyong City
#
#                                                 Locality Verbose   Longitude  \
# Restaurant ID
# 6317637        Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 6304287        Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 6300002        Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# ...

# %%
df['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64

# %%
df['Restaurant Name'].unique()
# Out:
# array(['Le Petit Souffle', 'Izakaya Kikufuji', 'Heat - Edsa Shangri-La',
#        ..., 'Huqqa', 'A\x81ô\x81ôk Kahve', "Walter's Coffee Roastery"],
#       dtype=object)

# %%
df['Locality'].unique()
# Out:
# array(['Century City Mall, Poblacion, Makati City',
#        'Little Tokyo, Legaspi Village, Makati City',
#        'Edsa Shangri-La, Ortigas, Mandaluyong City', ..., 'Ko\x81ôuyolu',
#        'Kuruí_e\x81ôme', 'Moda'], dtype=object)

# %%
df
# Out:
#                         Restaurant Name              City  \
# Restaurant ID
# 6317637                Le Petit Souffle       Makati City
# 6304287                Izakaya Kikufuji       Makati City
# 6300002          Heat - Edsa Shangri-La  Mandaluyong City
# 6318506                            Ooma  Mandaluyong City
# 6314302                     Sambo Kojin  Mandaluyong City
# ...                                 ...               ...
# 5915730                    NamlÛ± Gurme         ÛÁstanbul
# 5908749                   Ceviz AÛôacÛ±         ÛÁstanbul
# 5915807                           Huqqa         ÛÁstanbul
# 5916112                    Aôôk Kahve         ÛÁstanbul
# 5927402        Walter's Coffee Roastery         ÛÁstanbul
#
#                                                  Locality  \
# Restaurant ID
# 6317637         Century City Mall, Poblacion, Makati City
# 6304287        Little Tokyo, Legaspi Village, Makati City
# 6300002        Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.nunique().to_frame('EXACT UNIQUE VALUES OF THE RESTURANCE')
# Out:
#                       EXACT UNIQUE VALUES OF THE RESTURANCE
# Restaurant Name                                        7446
# City                                                    141
# Locality                                               1208
# Locality Verbose                                       1265
# Longitude                                              8120
# Latitude                                               8677
# Cuisines                                               1825
# Average Cost for two                                    140
# Currency                                                 12
# Has Table booking                                         2
# Has Online delivery                                       2
# Is delivering now                                         2
# Switch to order menu                                      1
# Price range                                               4
# Aggregate rating                                         33
# ...

# %% [markdown]
# # DATA VISUALIZATION APPLICATIONS

# %%
sns.countplot(x='Rating text',palette='coolwarm',data=df,hue='Price range')


#The average RATE for prIce range of one and two was 1500 count.
#In all the RATING, THERE WAS HIGH AMOUNT OF PEOPLE WHICH DID NOT RATE IN PRICE RANCE OF 1
# Out:
# <Axes: xlabel='Rating text', ylabel='count'>

# %%
zom= sns.countplot(x='Price range',data=df)

print(df['Price range'].value_counts())



#THE GRAPH SHOWS THAT AS THE NUMBER OF PRICE RANGE DECREASE NEGATIVELY.
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
sns.countplot(x='Is delivering now',palette='coolwarm',data=df,hue='Price range')

#THE POPULATION OF PEOPLE WHO DID NOT GET THERE DELIVERY IMMEDIATELY WAS VERY HIGH WHEN COMPARED TO THE POPULATION THAT GOT THERE PRODUCT.
# Out:
# <Axes: xlabel='Is delivering now', ylabel='count'>

# %%
sns.countplot(x='Price range',palette='coolwarm',data=df,hue='Is delivering now')

df['Price range'].value_counts()


#AS THE PRICE RANGE INCREASE, THE POPULATION OF PEOPLE WHO DID NOT GET DELIVERY INCREASE
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
sns.countplot(y='Currency',palette='coolwarm',data=df,hue='Price range')
# Out:
# <Axes: xlabel='count', ylabel='Currency'>

# %%
sns.countplot(x='Switch to order menu',palette='coolwarm',data=df,hue='Price range')


#THE GRAPH SHOWS THERE WAS NO SWITCH OF ANY ORDER
# Out:
# <Axes: xlabel='Switch to order menu', ylabel='count'>

# %%
zom= sns.countplot(x='Rating color',data=df)

print(df['Price range'].value_counts())
#ORANGE WAS RATED VERY HIGH WHEN COMPARED TO OTHERS COLOR BUT RED SHOWED THE LEAST RATE.
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
sns.countplot(x='Rating color',palette='coolwarm',data=df,hue='Price range')
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
sns.distplot(df['Average Cost for two'], color = 'm', kde_kws = {'shade':True}, hist = False)

plt.show()

# %%
sns.countplot(x='Aggregate rating', palette='coolwarm', data=df)


plt.show()

# %%
sns.distplot(df['Aggregate rating'], color = 'm', kde_kws = {'shade':True}, hist = False)

plt.show()

# %%
cal =  ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

le=LabelEncoder()

# %%
cal =  ['Restaurant Name', 'City','Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']

for zo in cal:
    df[zo]=le.fit_transform(df[zo].astype(str))

# %%
df
# Out:
#                Restaurant Name  City  Locality  Locality Verbose   Longitude  \
# Restaurant ID
# 6317637                   3749    73       171               172  121.027535
# 6304287                   3173    73       593               601  121.014101
# 6300002                   2897    75       308               314  121.056831
# 6318506                   4707    75       862               875  121.056475
# 6314302                   5523    75       862               875  121.057508
# ...                        ...   ...       ...               ...         ...
# 5915730                   4443   140       517               523   28.977392
# 5908749                   1311   140       552               558   29.041297
# 5915807                   3069   140       554               561   29.034640
# 5916112                    513   140       554               561   29.036019
# 5927402                   7240   140       670               681   29.026016
#
# ...

# %%
df
# Out:
#                Restaurant Name  City  Locality  Locality Verbose   Longitude  \
# Restaurant ID
# 6317637                   3749    73       171               172  121.027535
# 6304287                   3173    73       593               601  121.014101
# 6300002                   2897    75       308               314  121.056831
# 6318506                   4707    75       862               875  121.056475
# 6314302                   5523    75       862               875  121.057508
# ...                        ...   ...       ...               ...         ...
# 5915730                   4443   140       517               523   28.977392
# 5908749                   1311   140       552               558   29.041297
# 5915807                   3069   140       554               561   29.034640
# 5916112                    513   140       554               561   29.036019
# 5927402                   7240   140       670               681   29.026016
#
# ...

# %%
df.drop('Switch to order menu', axis=1, inplace=True)

# %%
df.describe()
# Out:
#        Restaurant Name         City     Locality  Locality Verbose  \
# count      9551.000000  9551.000000  9551.000000       9551.000000
# mean       3653.204586    78.301434   658.128468        677.304994
# std        2142.917876    23.198915   315.866515        331.727449
# min           0.000000     0.000000     0.000000          0.000000
# 25%        1777.500000    76.000000   381.000000        387.000000
# 50%        3595.000000    88.000000   696.000000        707.000000
# 75%        5485.500000    88.000000   921.000000        953.000000
# max        7445.000000   140.000000  1207.000000       1264.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# min    -157.948486   -41.330428     0.00000              0.000000
# ...

# %%
df.corr()
# Out:
#                       Restaurant Name      City  Locality  Locality Verbose  \
# Restaurant Name              1.000000 -0.001399  0.004322          0.004281
# City                        -0.001399  1.000000  0.096444          0.093142
# Locality                     0.004322  0.096444  1.000000          0.999465
# Locality Verbose             0.004281  0.093142  0.999465          1.000000
# Longitude                   -0.001920  0.117391  0.086448          0.084342
# Latitude                     0.009922 -0.004301 -0.020424         -0.020905
# Cuisines                     0.051496  0.025764  0.006499          0.005483
# Average Cost for two         0.019241 -0.028838 -0.012136         -0.011852
# Currency                     0.009669 -0.071996  0.023723          0.022966
# Has Table booking            0.041173 -0.003762 -0.065594         -0.065132
# Has Online delivery          0.028082  0.012723 -0.030993         -0.031766
# ...

# %%
plt.figure(figsize = (20,15))

sns.heatmap(df.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
plt.figure(figsize=(22, 7))

df.corr()['Price range'].sort_values(ascending = False).drop(['Price range']).plot(kind='bar',color='m')

plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title('Correlation between the label as PRICE RANGE and feature using barplot', fontsize = 20)

plt.show()

#THERE IS MINIMUM CORRELATION BETWEEN THE TABLE BOOKING AND LOCALITY VERBOSE. 
#PRICE RANGE, VOTES AND LATITUDE HAS HIGH CORRELATION

# %%
plt.figure(figsize=(22, 7))

df.corr()['Average Cost for two'].sort_values(ascending = False).drop(['Average Cost for two']).plot(kind='bar',color='m')

plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title('Correlation between the label AS AVERAGE COST FOR TWO and feature using barplot', fontsize = 20)

plt.show()


#THERE IS MINIMUM CORRELATION BETWEEN THE TABLE BOOKING AND LOCALITY VERBOSE. 
#PRICE RANGE, VOTES AND LATITUDE HAS HIGH CORRELATION

# %%
df.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))


#THERE IS PRESENCE OF OUTLIERS IN CITY, LONGITUDE, LATITUDE,TABLE BOOKING,DELIVERY NOW,PRICE RANGE, AGGREGATING RATING AND VOTES
# Out:
# Restaurant Name            Axes(0.125,0.712609;0.110714x0.167391)
# City                    Axes(0.257857,0.712609;0.110714x0.167391)
# Locality                Axes(0.390714,0.712609;0.110714x0.167391)
# Locality Verbose        Axes(0.523571,0.712609;0.110714x0.167391)
# Longitude               Axes(0.656429,0.712609;0.110714x0.167391)
# Latitude                Axes(0.789286,0.712609;0.110714x0.167391)
# Cuisines                   Axes(0.125,0.511739;0.110714x0.167391)
# Average Cost for two    Axes(0.257857,0.511739;0.110714x0.167391)
# Currency                Axes(0.390714,0.511739;0.110714x0.167391)
# Has Table booking       Axes(0.523571,0.511739;0.110714x0.167391)
# Has Online delivery     Axes(0.656429,0.511739;0.110714x0.167391)
# Is delivering now       Axes(0.789286,0.511739;0.110714x0.167391)
# Price range                 Axes(0.125,0.31087;0.110714x0.167391)
# Aggregate rating         Axes(0.257857,0.31087;0.110714x0.167391)
# ...

# %%
df.skew()
# Out:
# Restaurant Name          0.044637
# City                    -1.193777
# Locality                -0.253554
# Locality Verbose        -0.183064
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
df
# Out:
#                Restaurant Name  City  Locality  Locality Verbose   Longitude  \
# Restaurant ID
# 6317637                   3749    73       171               172  121.027535
# 6304287                   3173    73       593               601  121.014101
# 6300002                   2897    75       308               314  121.056831
# 6318506                   4707    75       862               875  121.056475
# 6314302                   5523    75       862               875  121.057508
# ...                        ...   ...       ...               ...         ...
# 5915730                   4443   140       517               523   28.977392
# 5908749                   1311   140       552               558   29.041297
# 5915807                   3069   140       554               561   29.034640
# 5916112                    513   140       554               561   29.036019
# 5927402                   7240   140       670               681   29.026016
#
# ...

# %%
x = df.drop('Price range', axis = 1)

y = df['Price range']

# %%
#PREPROCESSING OF ZOMATO RESTURANCE TO REMOVE THE OUTLIER USING STANDARDSCALER



from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x=pd.DataFrame(scaler.fit_transform(x), columns = x.columns)

x
# Out:
#       Restaurant Name      City  Locality  Locality Verbose  Longitude  \
# 0            0.044706 -0.228533 -1.542278         -1.523333   1.372269
# 1           -0.224101 -0.228533 -0.206201         -0.230035   1.371945
# 2           -0.352904 -0.142317 -1.108528         -1.095249   1.372975
# 3            0.491783 -0.142317  0.645470          0.595987   1.372966
# 4            0.872592 -0.142317  0.645470          0.595987   1.372991
# ...               ...       ...       ...               ...        ...
# 9546         0.368580  2.659685 -0.446821         -0.465180  -0.847685
# 9547        -1.093055  2.659685 -0.336009         -0.359666  -0.846144
# 9548        -0.272635  2.659685 -0.329677         -0.350622  -0.846305
# 9549        -1.465464  2.659685 -0.329677         -0.350622  -0.846272
# 9550         1.673878  2.659685  0.037586          0.011139  -0.846513
#
#       Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# ...

# %%
#Finding variance inflation factor in each scaled column ie x.shape[1] (1/(1-R2))


from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()



vif['VIF values'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

vif['Features'] = x.columns

vif

#This shows that locality and lacality verbose have the VIF greater than 10 with highest correlation value. 
#At this point, the locality is to be removed
# Out:
#     VIF values              Features
# 0     1.006611       Restaurant Name
# 1     1.074882                  City
# 2   951.787323              Locality
# 3   950.614723      Locality Verbose
# 4     1.327330             Longitude
# 5     1.063516              Latitude
# 6     1.038271              Cuisines
# 7     1.025400  Average Cost for two
# 8     1.180540              Currency
# 9     1.094421     Has Table booking
# 10    1.146501   Has Online delivery
# 11    1.012340     Is delivering now
# 12    1.523945      Aggregate rating
# 13    1.214954          Rating color
# 14    1.256406           Rating text
# 15    1.236285                 Votes

# %%
x.drop('Locality',axis=1,inplace=True)

# %%
#Again checking VIF value to confirm whether the multicollinearity still exist or not

vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]

vif['Features'] = x.columns


vif
# Out:
#     VIF values              Features
# 0     1.006608       Restaurant Name
# 1     1.065618                  City
# 2     1.049348      Locality Verbose
# 3     1.325873             Longitude
# 4     1.063437              Latitude
# 5     1.037944              Cuisines
# 6     1.025362  Average Cost for two
# 7     1.180249              Currency
# 8     1.094172     Has Table booking
# 9     1.146015   Has Online delivery
# 10    1.012339     Is delivering now
# 11    1.522401      Aggregate rating
# 12    1.214073          Rating color
# 13    1.255513           Rating text
# 14    1.236284                 Votes

# %% [markdown]
# # THE ABOVE VIF SHOWS THAT THE ISSUE OF MULTICOLLINEARITY IS NOW RESOLVED

# %%
y.value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
#Oversampling the data



from imblearn.over_sampling import SMOTE

SM = SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
#checking value count of target column

y.value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
y1.value_counts()


#THE TARGET VARIABLE FOR PRICE IS EQUAL
# Out:
# Price range
# 3    4444
# 4    4444
# 2    4444
# 1    4444
# Name: count, dtype: int64

# %%
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

from sklearn.neighbors import KNeighborsClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.30, random_state =42)

# %%
x_train
# Out:
#        Restaurant Name      City  Locality Verbose  Longitude  Latitude  \
# 11542        -1.318235  2.185500          1.539582  -3.555801  0.452352
# 14508        -0.278756  0.418083         -1.312495   0.317359  0.249301
# 1415          1.668278 -1.220010         -1.258041   0.312587  0.236871
# 16951        -0.447206  0.299555         -0.716842  -1.546527 -2.348827
# 12280         1.098434 -0.129956         -0.482652   0.236138 -0.402041
# ...                ...       ...               ...        ...       ...
# 11284        -0.603094  0.812431          0.320072  -3.642322  0.422721
# 11964        -1.269341  0.418083         -1.451221   0.315851  0.255510
# 5390         -0.085498  0.418083         -0.022022   0.315138  0.242878
# 860          -1.394996 -1.866626          0.517606   0.336058  0.407739
# 15795        -0.691198  0.418083         -0.446177   0.316066  0.246494
#
#        Cuisines  Average Cost for two  Currency  Has Table booking  \
# ...

# %%
x_train.shape
# Out:
# (12443, 15)

# %%
x_test.shape
# Out:
# (5333, 15)

# %%
y_train.shape
# Out:
# (12443,)

# %%
y_test.shape
# Out:
# (5333,)

# %%
KNN=KNeighborsClassifier(n_neighbors=5)

KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
KNNpred=KNN.predict(x_test)

# %%
KNNpred
# Out:
# array([1, 3, 3, ..., 1, 4, 4], dtype=int64)

# %%
accuracy_score(y_test, KNNpred)
# Out:
# 0.7344834052128258

# %%
print(confusion_matrix(y_test,KNNpred))
# Out:
# [[ 912  346   47   25]
#  [ 347  757  178   56]
#  [  79  102 1021  147]
#  [  21   12   56 1227]]

# %%
print(classification_report(y_test, KNNpred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.69      0.68      1330
#            2       0.62      0.57      0.59      1338
#            3       0.78      0.76      0.77      1349
#            4       0.84      0.93      0.89      1316
#
#     accuracy                           0.73      5333
#    macro avg       0.73      0.74      0.73      5333
# weighted avg       0.73      0.73      0.73      5333

# %%
from sklearn import svm

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
predsvc=svc.predict(x_test)

# %%
predsvc
# Out:
# array([1, 3, 3, ..., 1, 4, 4], dtype=int64)

# %%
print(accuracy_score(y_test,predsvc))
# Out:
# 0.6607912994562161

# %%
print(confusion_matrix(y_test,predsvc))
# Out:
# [[1039  234   46   11]
#  [ 519  566  189   64]
#  [ 100  130  857  262]
#  [  61   19  174 1062]]

# %%
print(classification_report(y_test,predsvc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.60      0.78      0.68      1330
#            2       0.60      0.42      0.49      1338
#            3       0.68      0.64      0.66      1349
#            4       0.76      0.81      0.78      1316
#
#     accuracy                           0.66      5333
#    macro avg       0.66      0.66      0.65      5333
# weighted avg       0.66      0.66      0.65      5333

# %%
#FROM THE ABOVE MACHINE LEARNING MODELS, IT SHOWS THAT KNEIGHBORSCLASSIFIER GAVE THE HIGHEST ACCURACY FOR PRICE PREDICTION OF 74%.
# FROM Price range
#1    4444
#2    3113
#3    1408
#4     586 THE PRICE OF 586 MADE A VERY GOOD PRECISION OF 86% WHILE PRICE 2(3113) SHOWED THE LEAST PRECISION OF THE MACHINE LEARNING.

# %%
import joblib

# %%
joblib.dump(KNN,'Zomato.PKI')
# Out:
# ['Zomato.PKI']
