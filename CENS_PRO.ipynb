# %%
import pandas as pd
import zipfile
from io import BytesIO
import seaborn as sns
import numpy as np

# %%
filepath=r"C:\Users\emeka\Downloads\census+income (1).zip"

# %%
with zipfile.ZipFile(filepath,"r") as f:
    f.namelist()

# %%
f.namelist()
# Out:
# ['adult.data', 'adult.names', 'adult.test', 'Index', 'old.adult.names']

# %%
with zipfile.ZipFile(filepath, "r") as f:
    with f.open('adult.data') as r:
        dat = pd.read_csv(r)

# %%
dat

#THIS IS THE DATA REQUIRED FOR THIS ANALYSIS
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
with zipfile.ZipFile(filepath, "r") as f:
    with f.open('Index') as r:
        df1 = pd.read_csv(r)

# %%
df1
# Out:
#                      Index of adult
# 0        02 Dec 1996      140 Index
# 1   10 Aug 1996  3974305 adult.data
# 2  10 Aug 1996     4267 adult.names
# 3   10 Aug 1996  2003153 adult.test

# %%
with zipfile.ZipFile(filepath, "r") as f:
    with f.open('adult.test') as r:
        df2 = pd.read_csv(r)

# %%
#The df2 data is for the  test

df2
# Out:
#                                                                                                                                                      |1x3 Cross validator
# 25  Private      226802  11th         7   Never-married       Machine-op-inspct  Own-child       Black               Male   0    0 40  United-States               <=50K.
# 38  Private      89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband         White               Male   0    0 50  United-States               <=50K.
# 28  Local-gov    336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband         White               Male   0    0 40  United-States                >50K.
# 44  Private      160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband         Black               Male   7688 0 40  United-States                >50K.
# ...

# %%
dat
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
dat.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
dat.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# ...

# %%
dat.dtypes
# Out:
# 39                 int64
#  State-gov        object
#  77516             int64
#  Bachelors        object
#  13                int64
#  Never-married    object
#  Adm-clerical     object
#  Not-in-family    object
#  White            object
#  Male             object
#  2174              int64
#  0                 int64
#  40                int64
#  United-States    object
#  <=50K            object
# dtype: object

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dat
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
dat.columns

#The numes of the columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
#To change the names of the columns

dat.columns=['AGE','Workclass','FnlWgt','Education','Eductional_number','Marital_Status','Occupation','Relation','Race','Sex','Capital_gain','Capital_loss','Hour_per_weeks','Native_Country','Income']

# %%
dat
# Out:
#        AGE          Workclass  FnlWgt    Education  Eductional_number  \
# 0       50   Self-emp-not-inc   83311    Bachelors                 13
# 1       38            Private  215646      HS-grad                  9
# 2       53            Private  234721         11th                  7
# 3       28            Private  338409    Bachelors                 13
# 4       37            Private  284582      Masters                 14
# ...    ...                ...     ...          ...                ...
# 32555   27            Private  257302   Assoc-acdm                 12
# 32556   40            Private  154374      HS-grad                  9
# 32557   58            Private  151910      HS-grad                  9
# 32558   22            Private  201490      HS-grad                  9
# 32559   52       Self-emp-inc  287927      HS-grad                  9
#
#             Marital_Status          Occupation        Relation    Race  \
# ...

# %%
dat.columns
# Out:
# Index(['AGE', 'Workclass', 'FnlWgt', 'Education', 'Eductional_number',
#        'Marital_Status', 'Occupation', 'Relation', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hour_per_weeks', 'Native_Country',
#        'Income'],
#       dtype='object')

# %%
for i in dat.columns:
    print(dat[i].value_counts())
    print("\n")

#There is presence of the ? values which was observed in column Occupation, Native-Country, Workclass.
# Out:
# AGE
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: count, Length: 73, dtype: int64
#
#
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64
#
#
# FnlWgt
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: count, Length: 21647, dtype: int64
#
#
# Education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
# ...

# %%
dat.head(8)
# Out:
#    AGE          Workclass  FnlWgt   Education  Eductional_number  \
# 0   50   Self-emp-not-inc   83311   Bachelors                 13
# 1   38            Private  215646     HS-grad                  9
# 2   53            Private  234721        11th                  7
# 3   28            Private  338409   Bachelors                 13
# 4   37            Private  284582     Masters                 14
# 5   49            Private  160187         9th                  5
# 6   52   Self-emp-not-inc  209642     HS-grad                  9
# 7   31            Private   45781     Masters                 14
#
#            Marital_Status          Occupation        Relation    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# 2      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3      Married-civ-spouse      Prof-specialty            Wife   Black
# ...

# %%
dat['Workclass'].value_counts()
# Out:
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %%
dat['Occupation'].value_counts()
# Out:
# Occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: count, dtype: int64

# %%
dat['Native_Country'].value_counts()
# Out:
# Native_Country
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
dat.head(50)
# Out:
#     AGE          Workclass  FnlWgt      Education  Eductional_number  \
# 0    50   Self-emp-not-inc   83311      Bachelors                 13
# 1    38            Private  215646        HS-grad                  9
# 2    53            Private  234721           11th                  7
# 3    28            Private  338409      Bachelors                 13
# 4    37            Private  284582        Masters                 14
# 5    49            Private  160187            9th                  5
# 6    52   Self-emp-not-inc  209642        HS-grad                  9
# 7    31            Private   45781        Masters                 14
# 8    42            Private  159449      Bachelors                 13
# 9    37            Private  280464   Some-college                 10
# 10   30          State-gov  141297      Bachelors                 13
# 11   23            Private  122272      Bachelors                 13
# 12   32            Private  205019     Assoc-acdm                 12
# ...

# %%
dat['Workclass'].value_counts()
# Out:
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %%
#The dataset has no empty values

dat.isnull().sum()
# Out:
# AGE                  0
# Workclass            0
# FnlWgt               0
# Education            0
# Eductional_number    0
# Marital_Status       0
# Occupation           0
# Relation             0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hour_per_weeks       0
# Native_Country       0
# Income               0
# dtype: int64

# %%
#The dataset contains 32560 entries with 15 columns

dat.shape
# Out:
# (32560, 15)

# %%
#The dataset contains itergers and object as its datatype

dat.dtypes
# Out:
# AGE                   int64
# Workclass            object
# FnlWgt                int64
# Education            object
# Eductional_number     int64
# Marital_Status       object
# Occupation           object
# Relation             object
# Race                 object
# Sex                  object
# Capital_gain          int64
# Capital_loss          int64
# Hour_per_weeks        int64
# Native_Country       object
# Income               object
# dtype: object

# %%
#The heatmap graph shows that all the dataset has not missing values

sns.heatmap(dat.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(dat.isnull(),cmap='cool_r')

#The null value is empty. The only different with the above is just that color map was included
# Out:
# <Axes: >

# %%
#To check for categorical columns

categorical_colum=[]
for i in dat.dtypes.index:
    if dat.dtypes[i]=="object":
        categorical_colum.append(i)
print("Categorical columns:",categorical_colum)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in dat.dtypes.index:
    if dat.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['Workclass', 'Education', 'Marital_Status', 'Occupation', 'Relation', 'Race', 'Sex', 'Native_Country', 'Income']
#
#
# Numerical columns: ['AGE', 'FnlWgt', 'Eductional_number', 'Capital_gain', 'Capital_loss', 'Hour_per_weeks']

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
{column:len(dat[column].unique()) for column in dat.select_dtypes('object').columns}
# Out:
# {'Workclass': 9,
#  'Education': 16,
#  'Marital_Status': 7,
#  'Occupation': 15,
#  'Relation': 6,
#  'Race': 5,
#  'Sex': 2,
#  'Native_Country': 42,
#  'Income': 2}

# %%
cat = ['Workclass', 'Education', 'Marital_Status', 'Occupation', 'Relation', 'Race', 'Sex', 'Native_Country', 'Income']

# %%
dat.nunique().to_frame("Number of unique value in the table")
# Out:
#                    Number of unique value in the table
# AGE                                                 73
# Workclass                                            9
# FnlWgt                                           21647
# Education                                           16
# Eductional_number                                   16
# Marital_Status                                       7
# Occupation                                          15
# Relation                                             6
# Race                                                 5
# Sex                                                  2
# Capital_gain                                       119
# Capital_loss                                        92
# Hour_per_weeks                                      94
# Native_Country                                      42
# Income                                               2

# %% [markdown]
# # FOR DATA VISUALIZATION

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(dat, hue='Income',palette='Dark2')


plt.show()

# %%
ma= sns.countplot(x='Income',data=dat)

print(dat['Income'].value_counts())
# Out:
# Income
#  <=50K    24719
#  >50K      7841
# Name: count, dtype: int64

# %% [markdown]
# # The dollar generated that is over  50k   are  less  when compared to the dollar that are  less than or equal to 50k

# %%
ya= sns.countplot(x='Sex',data=dat)

print(dat['Sex'].value_counts())

#MALE HAS THE HIGHEST POPULATION OF CENSUS WHEN COMPARED TO THE FEMALE
# Out:
# Sex
#  Male      21789
#  Female    10771
# Name: count, dtype: int64

# %% [markdown]
# In the census population, The graph shows that male are high in population(21789) when compared to female (10771)

# %%
ma= sns.countplot(x='Income',data=dat,hue='Race', palette='coolwarm')

#GREATER POPULATION OF WHITE EARN <=50K AND ALSO EARN GREATER INCOME THAT IS >50K

# %%
ma= sns.countplot(x='Income',data=dat,hue='Relation', palette='coolwarm')

#RELATIONS THAT ARE NOT IN FAMILY ARE MOSTLTY FIND IN JOB PAY OF <=50K WHILE GREATER POPULATION OF HASBAND EARN>=50K

# %%
ma= sns.countplot(x='Income',data=dat,hue='Occupation', palette='coolwarm')

# %%
ma= sns.countplot(x='Income',data=dat,hue='Workclass', palette='coolwarm')

# %%
Ra= sns.countplot(x='Race',data=dat)

print(dat['Race'].value_counts())

#The graph shows that the population of race varies. The white are more populated in the census, fllowed by black, Asiah-pac-Islander, and other has the least population
# Out:
# Race
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: count, dtype: int64

# %%
Re= sns.countplot(x='Relation',data=dat)

print(dat['Relation'].value_counts())

#This graph shows that Husband has the highest population census while other-relatives shows the least population count.
# Out:
# Relation
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: count, dtype: int64

# %%
marital= sns.countplot(x='Marital_Status',data=dat)

print(dat['Marital_Status'].value_counts())

#married-civ-spouse and never-married shows higher in census count while married-AF-spouse shows the least population in the graph.
# Out:
# Marital_Status
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: count, dtype: int64

# %%
wc= sns.countplot(x='Workclass',data=dat)

print(dat['Workclass'].value_counts())

#The population of people that work in private film are more when compared to others but people who never-worked are very infinitestimal
# Out:
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %%
OCC= sns.histplot(y='Occupation',data=dat)

print(dat['Occupation'].value_counts())

#The population of Prof-specialty ,Craft-repair, Exec-managerial are slightly varied in count while Armed-Force are the least in population of occupation
# Out:
# Occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: count, dtype: int64

# %%
EDU= sns.histplot(x='Education',data=dat)

print(dat['Education'].value_counts())

# people with HS-grad are more in population while Preschool is the least during the census.
# Out:
# Education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: count, dtype: int64

# %%
dat.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))
# Out:
# AGE                     Axes(0.125,0.712609;0.110714x0.167391)
# FnlWgt               Axes(0.257857,0.712609;0.110714x0.167391)
# Eductional_number    Axes(0.390714,0.712609;0.110714x0.167391)
# Capital_gain         Axes(0.523571,0.712609;0.110714x0.167391)
# Capital_loss         Axes(0.656429,0.712609;0.110714x0.167391)
# Hour_per_weeks       Axes(0.789286,0.712609;0.110714x0.167391)
# dtype: object

# %% [markdown]
# There is presence of outliers in the above dataset

# %%
plt.figure(figsize = (10,6), facecolor='white')

plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        ax=plt.subplot(2, 2, plotnumber)
        sns.distplot(dat[col],color = 'm')
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()


#The Age and FnlWgt graph are skewed to the right, capital-gain at more are more in population and the education_number varies with some outliers but between 7.5 and 10 shows greater eduction-number.

# %%
dat
# Out:
#        AGE          Workclass  FnlWgt    Education  Eductional_number  \
# 0       50   Self-emp-not-inc   83311    Bachelors                 13
# 1       38            Private  215646      HS-grad                  9
# 2       53            Private  234721         11th                  7
# 3       28            Private  338409    Bachelors                 13
# 4       37            Private  284582      Masters                 14
# ...    ...                ...     ...          ...                ...
# 32555   27            Private  257302   Assoc-acdm                 12
# 32556   40            Private  154374      HS-grad                  9
# 32557   58            Private  151910      HS-grad                  9
# 32558   22            Private  201490      HS-grad                  9
# 32559   52       Self-emp-inc  287927      HS-grad                  9
#
#             Marital_Status          Occupation        Relation    Race  \
# ...

# %%
dat.head()
# Out:
#    AGE          Workclass  FnlWgt   Education  Eductional_number  \
# 0   50   Self-emp-not-inc   83311   Bachelors                 13
# 1   38            Private  215646     HS-grad                  9
# 2   53            Private  234721        11th                  7
# 3   28            Private  338409   Bachelors                 13
# 4   37            Private  284582     Masters                 14
#
#         Marital_Status          Occupation        Relation    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hour_per_weeks  Native_Country  Income
# ...

# %% [markdown]
# # APPLYING LABEL ENCODER TO CONVERT CATEGORICAL DATA TO THE NUMERICAL VALUES IN THE TABLE

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

le=LabelEncoder()

# %%
list1=['Workclass', 'Education', 'Marital_Status', 'Occupation', 'Relation', 'Race', 'Sex', 'Native_Country', 'Income']

for mal in list1:
    dat[mal]=le.fit_transform(dat[mal].astype(str))

# %%
dat.head(8)
# Out:
#    AGE  Workclass  FnlWgt  Education  Eductional_number  Marital_Status  \
# 0   50          6   83311          9                 13               2
# 1   38          4  215646         11                  9               0
# 2   53          4  234721          1                  7               2
# 3   28          4  338409          9                 13               2
# 4   37          4  284582         12                 14               2
# 5   49          4  160187          6                  5               3
# 6   52          6  209642         11                  9               2
# 7   31          4   45781         12                 14               4
#
#    Occupation  Relation  Race  Sex  Capital_gain  Capital_loss  \
# 0           4         0     4    1             0             0
# 1           6         1     4    1             0             0
# 2           6         0     2    1             0             0
# 3          10         5     2    0             0             0
# ...

# %%
dat.dtypes
# Out:
# AGE                  int64
# Workclass            int32
# FnlWgt               int64
# Education            int32
# Eductional_number    int64
# Marital_Status       int32
# Occupation           int32
# Relation             int32
# Race                 int32
# Sex                  int32
# Capital_gain         int64
# Capital_loss         int64
# Hour_per_weeks       int64
# Native_Country       int32
# Income               int32
# dtype: object

# %%
dat.isnull().sum()
# Out:
# AGE                  0
# Workclass            0
# FnlWgt               0
# Education            0
# Eductional_number    0
# Marital_Status       0
# Occupation           0
# Relation             0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hour_per_weeks       0
# Native_Country       0
# Income               0
# dtype: int64

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AGE                32560 non-null  int64
#  1   Workclass          32560 non-null  int32
#  2   FnlWgt             32560 non-null  int64
#  3   Education          32560 non-null  int32
#  4   Eductional_number  32560 non-null  int64
#  5   Marital_Status     32560 non-null  int32
#  6   Occupation         32560 non-null  int32
#  7   Relation           32560 non-null  int32
#  8   Race               32560 non-null  int32
#  9   Sex                32560 non-null  int32
#  10  Capital_gain       32560 non-null  int64
#  11  Capital_loss       32560 non-null  int64
#  12  Hour_per_weeks     32560 non-null  int64
#  13  Native_Country     32560 non-null  int32
#  14  Income             32560 non-null  int32
# dtypes: int32(9), int64(6)
# memory usage: 2.6 MB

# %%
dat.describe()
# Out:
#                 AGE     Workclass        FnlWgt     Education  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000
# mean      38.581634      3.868796  1.897818e+05     10.298249
# std       13.640642      1.455879  1.055498e+05      3.870317
# min       17.000000      0.000000  1.228500e+04      0.000000
# 25%       28.000000      4.000000  1.178315e+05      9.000000
# 50%       37.000000      4.000000  1.783630e+05     11.000000
# 75%       48.000000      4.000000  2.370545e+05     12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000
#
#        Eductional_number  Marital_Status    Occupation      Relation  \
# count       32560.000000    32560.000000  32560.000000  32560.000000
# mean           10.080590        2.611794      6.572912      1.446376
# std             2.572709        1.506225      4.228809      1.606794
# min             1.000000        0.000000      0.000000      0.000000
# ...

# %%
dat.corr()
# Out:
#                         AGE  Workclass    FnlWgt  Education  \
# AGE                1.000000   0.003786 -0.076646  -0.010508
# Workclass          0.003786   1.000000 -0.016587   0.023537
# FnlWgt            -0.076646  -0.016587  1.000000  -0.028156
# Education         -0.010508   0.023537 -0.028156   1.000000
# Eductional_number  0.036527   0.052015 -0.043159   0.359172
# Marital_Status    -0.266292  -0.064798  0.028184  -0.038398
# Occupation        -0.020946   0.255004  0.001554  -0.021274
# Relation          -0.263698  -0.090449  0.008922  -0.010879
# Race               0.028718   0.049720 -0.021278   0.014135
# Sex                0.088832   0.095942  0.026882  -0.027349
# Capital_gain       0.077674   0.033828  0.000437   0.030047
# Capital_loss       0.057775   0.012231 -0.010259   0.016744
# Hour_per_weeks     0.068756   0.138974 -0.018770   0.055510
# Native_Country    -0.001151  -0.007710 -0.051957   0.064291
# Income             0.234039   0.051645 -0.009481   0.079311
#
# ...

# %%
plt.figure(figsize = (20,15))

sns.heatmap(dat.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
plt.figure(figsize=(22, 7))

dat.corr()['Income'].sort_values(ascending = False).drop(['Income']).plot(kind='bar',color='m')

plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title('Correlation between the label and feature using barplot', fontsize = 20)

plt.show()

#NATIVE COUNTRY AND FNLWGT HAS THE LEAST CORRELATION WHEN COMPARED TO OTHERS

# %% [markdown]
# # TO REMOVE OUTLIERS

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
z=np.abs(zscore(dat))

z
# Out:
#             AGE  Workclass    FnlWgt  Education  Eductional_number  \
# 0      0.837097   1.463883  1.008742   0.335443           1.134779
# 1      0.042640   0.090121  0.245046   0.181319           0.420027
# 2      1.057031   0.090121  0.425770   2.402489           1.197429
# 3      0.775755   0.090121  1.408146   0.335443           1.134779
# 4      0.115952   0.090121  0.898170   0.439700           1.523480
# ...         ...        ...       ...        ...                ...
# 32555  0.849066   0.090121  0.639710   0.852204           0.746077
# 32556  0.103982   0.090121  0.335466   0.181319           0.420027
# 32557  1.423589   0.090121  0.358811   0.181319           0.420027
# 32558  1.215624   0.090121  0.110927   0.181319           0.420027
# 32559  0.983720   0.777002  0.929862   0.181319           0.420027
#
#        Marital_Status  Occupation  Relation      Race       Sex  Capital_gain  \
# 0            0.406183    0.608434  0.900177  0.393675  0.703087      0.145914
# ...

# %%
#Taking the threshold to be 3

print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
dat=dat[(z<3).all(axis=1)]

dat
# Out:
#        AGE  Workclass  FnlWgt  Education  Eductional_number  Marital_Status  \
# 0       50          6   83311          9                 13               2
# 1       38          4  215646         11                  9               0
# 2       53          4  234721          1                  7               2
# 4       37          4  284582         12                 14               2
# 5       49          4  160187          6                  5               3
# ...    ...        ...     ...        ...                ...             ...
# 32555   27          4  257302          7                 12               2
# 32556   40          4  154374         11                  9               2
# 32557   58          4  151910         11                  9               6
# 32558   22          4  201490         11                  9               4
# 32559   52          5  287927         11                  9               2
#
# ...

# %% [markdown]
# # THE ABOVE IS THE PREPROCESSED DATA BY ZSCORE

# %%
x = dat.drop('Income', axis = 1)

y = dat['Income']

# %%
y.value_counts()

#the value value are not balanced
# Out:
# Income
# 0    21279
# 1     6138
# Name: count, dtype: int64

# %%
#Oversampling the data



from imblearn.over_sampling import SMOTE

SM = SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
#To check the value count of target column

y.value_counts()
# Out:
# Income
# 0    21279
# 1     6138
# Name: count, dtype: int64

# %%
y1.value_counts()
# Out:
# Income
# 0    21279
# 1    21279
# Name: count, dtype: int64

# %% [markdown]
# # MACHINE MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
maxAccu = 0
maxRS = 0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.30, random_state =i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best accuracy is ', maxAccu, 'at random_state', maxRS)
# Out:
# Best accuracy is  0.8988878446115288 at random_state 80

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, roc_curve

# %%
RFC= RandomForestClassifier()

RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predRFC=RFC.predict(x_test)

# %%
print(accuracy_score(y_test,predRFC))

print(confusion_matrix(y_test, predRFC))

print(classification_report(y_test,predRFC ))
# Out:
# 0.8905858395989975
# [[5647  716]
#  [ 681 5724]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      6363
#            1       0.89      0.89      0.89      6405
#
#     accuracy                           0.89     12768
#    macro avg       0.89      0.89      0.89     12768
# weighted avg       0.89      0.89      0.89     12768

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predGB=GB.predict(x_test)

# %%
print(accuracy_score(y_test,predGB))

print(confusion_matrix(y_test,predGB))

print(classification_report(y_test,predGB))
# Out:
# 0.8741384711779449
# [[5480  883]
#  [ 724 5681]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      6363
#            1       0.87      0.89      0.88      6405
#
#     accuracy                           0.87     12768
#    macro avg       0.87      0.87      0.87     12768
# weighted avg       0.87      0.87      0.87     12768

# %%
#THE MACHINE LEARNING USING THE RANDOMFORESTCLASSIFIER SHOWS THAT THERE IS 89% ACCURACY THAT THERE ARE PEOPLE THAT EARN OVER $50K A YEAR.
#THERE POPULATION THAT MAKE OVER $50K ARE 6138 IN THE OVERALL. THE PRECISION IS 89%.

# %%
import joblib

# %%
joblib.dump(RFC,'CensusIncome.PKI')
# Out:
# ['CensusIncome.PKI']
