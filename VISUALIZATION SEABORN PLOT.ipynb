# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
a=np.array(['juice','Apple','Mangos'])
b=np.array([100,200,300])
sns.stripplot(x=a,y=b)
# Out:
# <Axes: >

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/emptest.csv')
df
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
df1emptest=pd.read_csv('emptest_csv')

df1emptest
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
sns.violinplot(x='Salary',data=df1emptest)
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.violinplot(y='Salary',data=df1emptest)
# Out:
# <Axes: ylabel='Salary'>

# %%
sns.violinplot(x='Age',data=df1emptest)
# Out:
# <Axes: xlabel='Age'>

# %%
dfiris=pd.read_csv('iris.csv')

dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df1iris=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/iris.csv')

df1iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.stripplot(x='class',y='petal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal length'>

# %%
sns.stripplot(x='class',y='sepal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal length'>

# %%
sns.stripplot(x='class',y='sepal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal width'>

# %%
sns.swarmplot(x='class',y='sepal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal width'>

# %%
sns.swarmplot(x='class',y='sepal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal length'>

# %%
sns.swarmplot(x='class',y='petal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal length'>

# %%
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.swarmplot(x='class',y='petal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal width'>

# %%
df1emptest
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
sns.stripplot(x='City',y='Salary',data=df1emptest)
# Out:
# <Axes: xlabel='City', ylabel='Salary'>

# %%
sns.swarmplot(x='City',y='Salary',data=df1emptest)
# Out:
# <Axes: xlabel='City', ylabel='Salary'>

# %%
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.swarmplot(x='class',y='petal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal width'>

# %%
sns.swarmplot(y='class',x='petal width',data=dfiris)
# Out:
# <Axes: xlabel='petal width', ylabel='class'>

# %%
sns.stripplot(y='class',x='petal width',data=dfiris)
# Out:
# <Axes: xlabel='petal width', ylabel='class'>

# %%
sns.stripplot(x='class',y='petal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal width'>

# %%
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dfiris['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
dfiris['petal width'].value_counts()
# Out:
# petal width
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: count, dtype: int64

# %%
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(x=dfiris['class'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.countplot(x=dfiris['class'])
#
# NameError: name 'sns' is not defined

# %%
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.get_dataset_names()
# Out:
# []

# %%
import seaborn as sns
import pandas as pd

# %%
df1iris=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/iris.csv')

df1iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(y=df1iris['class'])
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
sns.countplot(x=df1iris['class'])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x=df1iris['sepal width'])
# Out:
# <Axes: xlabel='sepal width', ylabel='count'>

# %%
sns.countplot(x=df1iris['sepal length'])
# Out:
# <Axes: xlabel='sepal length', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dftips=pd.read_csv('tips.csv')
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dstitanic=pd.read_csv('titanic.csv')
dstitanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# []

# %%
sns.violinplot(x='total_bill',data=dftips)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(x='tip',data=dftips)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.violinplot(x='size',data=dftips)
# Out:
# <Axes: xlabel='size'>

# %%
sns.countplot(x=dftips['size'])
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
dftips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x='day',y='total_bill',data=dftips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(data=dftips,x='total_bill',bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=dftips,x='tip',bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.distplot(dftips['tip'],bins=10)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(dftips['total_bill'],bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#data will overspread. This is because data values was not upto 100. Note bins depends on data values

sns.distplot(dftips['total_bill'],bins=100)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#when you don't assign bins it will assume a defaut value of 10.


sns.distplot(dftips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(dftips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(dftips['total_bill'],bins=10,kde=False)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(dftips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(dftips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(dftips['size'])
# Out:
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.jointplot(data=dftips,x='total_bill',y='tip')

# %%
sns.jointplot(data=dftips,x='size',y='tip')

# %%
sns.rugplot(data=tips,x='tip')
# Out:
# <Axes: xlabel='tip'>

# %%
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
dstitanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
titanicds=pd.read_csv('titanic.csv')

titanicds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: object

# %%
titanicds['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanicds['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
#This is very important as it gives the exact count of the value

titanicds['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
#for countplot

sns.countplot(x=titanicds['class'])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x=titanicds['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
titanicds['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.catplot(x='pclass',y='fare',data=titanicds,hue='sex',kind='bar')

# %%
titanicds['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.catplot(x='class',y='survived',data=titanicds,kind='bar')

# %%
#You can assign code to it eg g but is not compulsory

g=sns.catplot(x='class',y='survived',data=titanicds,kind='bar')

# %%
sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='bar')

# %%
# strip is not a good one here as it cannot be interpreted properly here


sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='strip')

# %%
#will be difficult to explain. Always use bar as it will be easy to interpret


sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='violin')

# %%
sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='box')

# %%
sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='boxen')

# %%
titanicds['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='point')

# %%
sns.catplot(x='class',y='survived',data=titanicds,hue='sex',kind='swarm')

# %%
dftips=pd.read_csv('tips.csv')
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x='day',y='total_bill',data=dftips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=dftips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(dftips)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpgds=pd.read_csv('mpg.csv')

mpgds
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(data=mpgds,x='mpg',y='weight')
# Out:
# <Axes: xlabel='mpg', ylabel='weight'>

# %%
sns.scatterplot(data=mpgds,y='mpg',x='horsepower')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
sns.lineplot(data=mpgds,x='mpg',y='weight')
# Out:
# <Axes: xlabel='mpg', ylabel='weight'>

# %%
sns.lineplot(data=mpgds,y='mpg',x='horsepower')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
sns.regplot(data=mpgds,x='mpg',y='weight')
# Out:
# <Axes: xlabel='mpg', ylabel='weight'>

# %%
sns.boxplot(data=mpgds,x='weight')
# Out:
# <Axes: xlabel='weight'>

# %%
sns.boxplot(data=mpgds,y='weight')
# Out:
# <Axes: ylabel='weight'>

# %%
sns.boxplot(data=mpgds,x='acceleration')
# Out:
# <Axes: xlabel='acceleration'>

# %%
sns.boxplot(data=mpgds,x='displacement')
# Out:
# <Axes: xlabel='displacement'>

# %%
sns.rugplot(data=mpgds,y='mpg',x='horsepower')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
sns.jointplot(data=mpgds,x='mpg',y='weight')

# %%
sns.jointplot(data=mpgds,x='mpg',y='weight',kind='kde')

# %%
sns.jointplot(data=mpgds,x='mpg',y='weight',kind='hex')

# %%
sns.stripplot(data=mpgds,x='origin',y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
mpgds['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
sns.swarmplot(data=mpgds,x='origin',y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.catplot(data=mpgds,x='origin',y='mpg',kind='box')

# %%
taxisds=pd.read_csv('taxis.csv')

taxisds
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
taxisds.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
taxisds['total'].value_counts()
# Out:
# total
# 9.30     146
# 11.30    129
# 11.80    122
# 9.80     121
# 10.30    121
#         ...
# 57.80      1
# 56.31      1
# 23.24      1
# 55.68      1
# 26.82      1
# Name: count, Length: 898, dtype: int64

# %%
taxisds['pickup_zone'].value_counts()
# Out:
# pickup_zone
# Midtown Center                         230
# Upper East Side South                  211
# Penn Station/Madison Sq West           210
# Clinton East                           208
# Midtown East                           198
#                                       ...
# Homecrest                                1
# Bedford Park                             1
# Riverdale/North Riverdale/Fieldston      1
# Hollis                                   1
# Hillcrest/Pomonok                        1
# Name: count, Length: 194, dtype: int64

# %%
#In this scatter plot, as the distance increases the fare increases. btw 60 fare and 20 distance many people travels but very few travel high distance

sns.scatterplot(data=taxisds,x='fare',y='distance')
# Out:
# <Axes: xlabel='fare', ylabel='distance'>

# %%
sns.lmplot(x='distance',y='fare',data=taxisds)

# %%
sns.lmplot(x='distance',y='fare',data=taxisds,hue='payment')

# %%
flight=pd.read_csv('flights.csv')
flight
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
import seaborn as sns
import pandas as pd
flight=pd.read_csv('flights.csv')
flight=flight.pivot(y='month',x='year','passengers')
# Out:
#   Cell In[102], line 4
#     flight=flight.pivot(y='month',x='year','passengers')
#                                                        ^
# SyntaxError: positional argument follows keyword argument
