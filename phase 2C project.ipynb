# %%
import pandas as pd

# %%
df=pd.read_csv('loan_prediction_train.csv')

df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1=pd.read_csv('loan_prediction_test.csv')

df1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# # FOR THE LOAN PREDICTION TRAIN THE BELOW ANALYSIS IS DONE FOR THE ELUCIDATION OF THE DATA

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# The above is the first five data in the table

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# The above loan_prediction_train has 614 rows entries and 13 columns in the data

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# The above are the columns for the loan prediction columns

# %%
df.columns.tolist()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# The data contains both float, int and object types

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# The above data shows that the columns with 0 has no empty data but gender has null value of(13), Married (3), dependents(15), self employed (32),loanAmount(22), loan_Amount_Team (14), credit_History(50). The values inside the bracket are the null values in each columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# The above data has 614 entries from 0 to 613, it contains 13 columns, Some columns shows contains null value, the data type of float and object. The memory usuage is 62.5+

# %%
#checking for the value count in all the columns in the data above



for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Loan_ID
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: count, Length: 614, dtype: int64
#
#
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64
#
#
# Married
# Yes    398
# No     213
# Name: count, dtype: int64
#
#
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
#
#
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
#
#
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64
#
#
# ApplicantIncome
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: count, Length: 505, dtype: int64
#
#
# CoapplicantIncome
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# ...

# %% [markdown]
# The above shows the entries in all the columns and the correspondings values it contains.

# %% [markdown]
# # FOR THE POSSIBLE DATA VISUALIZATION OF THE ABOVE DATA IS DEPICTED BELOW

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.nunique().to_frame('DIFFERENT UNIQUE VALUE')
# Out:
#                    DIFFERENT UNIQUE VALUE
# Loan_ID                               614
# Gender                                  2
# Married                                 2
# Dependents                              4
# Education                               2
# Self_Employed                           2
# ApplicantIncome                       505
# CoapplicantIncome                     287
# LoanAmount                            203
# Loan_Amount_Term                       10
# Credit_History                          2
# Property_Area                           3
# Loan_Status                             2

# %%
sns.countplot(x='Loan_Status',data=df)

print(df['Loan_Status'].value_counts())
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %% [markdown]
# The above loan_status shows that people that uses loan status are 422 while 192 do not use loan.

# %%
sns.countplot(x='Gender',data=df)

print(df['Gender'].value_counts())
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %% [markdown]
# The data above shows that there are two genders where male male dominate (489) and they have fewer female which are 112 in the population.

# %%
sns.countplot(x='Married',data=df)

print(df['Married'].value_counts())
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %% [markdown]
# The population shows that married people are 398 while 213 are not married. It also shows that greater number of the populations are married.

# %%
sns.countplot(x='Dependents', hue='Loan_Status', data=df)

print(df[['Dependents','Loan_Status']].value_counts())
# Out:
# Dependents  Loan_Status
# 0           Y              238
#             N              107
# 2           Y               76
# 1           Y               66
#             N               36
# 3+          Y               33
# 2           N               25
# 3+          N               18
# Name: count, dtype: int64

# %% [markdown]
# The above shows that people that do not have dependents(0) use more of the loan when compared to people with one, two or plus three dependents.
# The population that uses loan are more in all the dependents and non dependents.
#
# The above graph also shows that the dependents who do not use loan decrease as the nunber of the dependents increases.

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.catplot(x='Self_Employed',y='Credit_History', hue='Loan_Status', data=df, kind ='bar')

print(df[['Self_Employed','Loan_Status','Credit_History']].value_counts())
# Out:
# Self_Employed  Loan_Status  Credit_History
# No             Y            1.0               306
#                N            1.0                81
#                             0.0                69
# Yes            Y            1.0                50
#                N            1.0                13
#                             0.0                12
# No             Y            0.0                 7
# Name: count, dtype: int64

# %% [markdown]
# From the above plot, it shows that the people with good credit_history get more loan when compared to people that do not have credit_history.
#
# In addition, people that are sel_employed has more credit history when compared to people that are not self employed.

# %%
sns.countplot(x='Property_Area', hue='Loan_Status', data=df)

print(df[['Property_Area','Loan_Status']].value_counts())
# Out:
# Property_Area  Loan_Status
# Semiurban      Y              179
# Urban          Y              133
# Rural          Y              110
#                N               69
# Urban          N               69
# Semiurban      N               54
# Name: count, dtype: int64

# %% [markdown]
# The population that got loan_status in semiurban are greater, followed by urban but the rural area are smaller.Whereas people that do not have loan_status in urban and rural are equal but smaller in semiurban region.

# %%
sns.kdeplot(df['Loan_Amount_Term'])

print(df['Loan_Amount_Term'].value_counts())
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %% [markdown]
# The skd graph shows that greater number of the population got more loan amount term between 300 and 400, followed by 100 and 200, as well as loan amount in 400 and 500 but from 0 to 100 shows the lowest level of loan_amount_term

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.distplot(df['ApplicantIncome'],bins=10,kde=True)

print(df['ApplicantIncome'].value_counts())
# Out:
# ApplicantIncome
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: count, Length: 505, dtype: int64

# %%
sns.distplot(df['CoapplicantIncome'],bins=10,kde=True)

print(df['CoapplicantIncome'].value_counts())
# Out:
# CoapplicantIncome
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# 2598.0      1
# 240.0       1
# Name: count, Length: 287, dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# # USING LABEL ENCODER TO CONVER CATEGORICAL DATA INTO NUMERICAL

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Married']=le.fit_transform(df['Married'])

# %%
df['Education']=le.fit_transform(df['Education'])

# %%
df['Self_Employed']=le.fit_transform(df['Self_Employed'])

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1         3+          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    int32
#  2   Married            614 non-null    int32
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    int32
#  5   Self_Employed      614 non-null    int32
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(4), int64(1), object(4)
# memory usage: 52.9+ KB

# %%
df["Dependents"]=df["Dependents"].replace(" ", np.nan)

df["LoanAmount"]=df["LoanAmount"].replace(" ", np.nan)

df["Loan_Amount_Term"]=df["Loan_Amount_Term"].replace(" ", np.nan)


df["Credit_History"]=df["Credit_History"].replace(" ", np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    int32
#  2   Married            614 non-null    int32
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    int32
#  5   Self_Employed      614 non-null    int32
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(4), int64(1), object(4)
# memory usage: 52.9+ KB

# %%
df.nunique()
# Out:
# Loan_ID              614
# Gender                 3
# Married                3
# Dependents             4
# Education              2
# Self_Employed          3
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1         3+          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    int32
#  2   Married            614 non-null    int32
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    int32
#  5   Self_Employed      614 non-null    int32
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(4), int64(1), object(4)
# memory usage: 52.9+ KB

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1         3+          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
        
df
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0        0.0       1        0         0.0          0              0
# 1        1.0       1        1         1.0          0              0
# 2        2.0       1        1         0.0          0              1
# 3        3.0       1        1         0.0          1              0
# 4        4.0       1        0         0.0          0              0
# ..       ...     ...      ...         ...        ...            ...
# 609    609.0       0        0         0.0          0              0
# 610    610.0       1        1         3.0          0              0
# 611    611.0       1        1         1.0          0              0
# 612    612.0       1        1         2.0          0              0
# 613    613.0       0        0         0.0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    float64
#  1   Gender             614 non-null    int32
#  2   Married            614 non-null    int32
#  3   Dependents         599 non-null    float64
#  4   Education          614 non-null    int32
#  5   Self_Employed      614 non-null    int32
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    float64
#  12  Loan_Status        614 non-null    float64
# dtypes: float64(8), int32(4), int64(1)
# memory usage: 52.9 KB

# %% [markdown]
# # THE MEANS OF DATA WITH MISSING VALUE

# %%
print('The mean value of LoanAmoun is:', df['Dependents'].mean())
# Out:
# The mean value of LoanAmoun is: 0.7629382303839732

# %%
print('The mean value of LoanAmount is:', df['LoanAmount'].mean())
# Out:
# The mean value of LoanAmount is: 146.41216216216216

# %%
print('The mean value of Loan_Amount_Term is:', df['Loan_Amount_Term'].mean())
# Out:
# The mean value of Loan_Amount_Term is: 342.0

# %%
print('The mean value of Credit_History is:', df['Credit_History'].mean())
# Out:
# The mean value of Credit_History is: 0.8421985815602837

# %% [markdown]
# # FILLING THE NAN WITH THE CALCULATED MEAN

# %%
df["Dependents"]=df["Dependents"].fillna(df["Dependents"].mean())

df["LoanAmount"]=df["LoanAmount"].fillna(df["LoanAmount"].mean())

df["Loan_Amount_Term"]=df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].mean())

df["Credit_History"]=df["Credit_History"].fillna(df["Credit_History"].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    float64
#  1   Gender             614 non-null    int32
#  2   Married            614 non-null    int32
#  3   Dependents         614 non-null    float64
#  4   Education          614 non-null    int32
#  5   Self_Employed      614 non-null    int32
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    float64
#  12  Loan_Status        614 non-null    float64
# dtypes: float64(8), int32(4), int64(1)
# memory usage: 52.9 KB

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# The above heatmap depict that the data does not have null value

# %%
df.describe()
# Out:
#           Loan_ID      Gender     Married  Dependents   Education  \
# count  614.000000  614.000000  614.000000  614.000000  614.000000
# mean   306.500000    0.838762    0.657980    0.762938    0.218241
# std    177.390811    0.421752    0.484971    1.002718    0.413389
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    153.250000    1.000000    0.000000    0.000000    0.000000
# 50%    306.500000    1.000000    1.000000    0.000000    0.000000
# 75%    459.750000    1.000000    1.000000    1.000000    0.000000
# max    613.000000    2.000000    2.000000    3.000000    1.000000
#
#        Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count     614.000000       614.000000         614.000000  614.000000
# mean        0.237785      5403.459283        1621.245798  146.412162
# std         0.534737      6109.041673        2926.248369   84.037468
# min         0.000000       150.000000           0.000000    9.000000
# ...

# %% [markdown]
# From above data decribe, the count show shows that there is no missing data as they are all equal.
#
# 50% (median) of the data in applicantincome,coapplicantincome, loanamount when compared to the mean skewed to left.
#
# There is presence of outliers as max value has greater difference when compared to the 75%

# %%
wu=df.corr()

# %%
plt.figure(figsize = (20,15))

sns.heatmap(df.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
wu['Loan_Status'].sort_values(ascending = False)
# Out:
# Loan_Status          1.000000
# Credit_History       0.567327
# Married              0.102595
# CoapplicantIncome    0.038806
# Property_Area        0.028109
# Gender               0.011524
# Dependents           0.010170
# Loan_ID              0.008108
# ApplicantIncome      0.007848
# Loan_Amount_Term    -0.011024
# Self_Employed       -0.025740
# LoanAmount          -0.027363
# Education           -0.103196
# Name: Loan_Status, dtype: float64

# %% [markdown]
# There is positive and negative correlation with the target

# %%
plt.figure(figsize=(22, 7))

df.corr()['Loan_Status'].sort_values(ascending = False).drop(['Loan_Status']).plot(kind='bar',color='m')

plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title('Correlation between the label and feature using barplot', fontsize = 20)

plt.show()

# %% [markdown]
# From the above, you can observe the positive and negative correlation between the feature and the target. Here Gender,Dependents,Loan_ID,Applicantincome and Loan_Amount_Team showss very low correlation when compared to others

# %%
df.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))
# Out:
# Loan_ID                 Axes(0.125,0.712609;0.110714x0.167391)
# Gender               Axes(0.257857,0.712609;0.110714x0.167391)
# Married              Axes(0.390714,0.712609;0.110714x0.167391)
# Dependents           Axes(0.523571,0.712609;0.110714x0.167391)
# Education            Axes(0.656429,0.712609;0.110714x0.167391)
# Self_Employed        Axes(0.789286,0.712609;0.110714x0.167391)
# ApplicantIncome         Axes(0.125,0.511739;0.110714x0.167391)
# CoapplicantIncome    Axes(0.257857,0.511739;0.110714x0.167391)
# LoanAmount           Axes(0.390714,0.511739;0.110714x0.167391)
# Loan_Amount_Term     Axes(0.523571,0.511739;0.110714x0.167391)
# Credit_History       Axes(0.656429,0.511739;0.110714x0.167391)
# Property_Area        Axes(0.789286,0.511739;0.110714x0.167391)
# Loan_Status              Axes(0.125,0.31087;0.110714x0.167391)
# dtype: object

# %% [markdown]
# THE ABOVE BOXPLOT SHOWS THAT THERE IS PRESENCE OF OUTLIERS IN GENDER, DEPENDENT, EDUCATION,SELF_EMPLOYMENT, APLLICANTINCOME,COAPPLICANTINCOME,LOAN_AMOUNT_TEAM AND CREDIT_HISTORY

# %%
#To check for the skewness of this data

df.skew()
# Out:
# Loan_ID              0.006474
# Gender              -0.980211
# Married             -0.527102
# Dependents           1.020836
# Education            1.299518
# Self_Employed        2.164757
# ApplicantIncome      2.115295
# CoapplicantIncome    1.369775
# LoanAmount           1.103178
# Loan_Amount_Term    -2.029308
# Credit_History      -1.862149
# Property_Area       -0.058055
# Loan_Status         -0.813560
# dtype: float64

# %% [markdown]
# # USING ZSCORE TO REMOVE THE OUTLIERS

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
z=np.abs(zscore(df))

z
# Out:
#       Loan_ID    Gender   Married  Dependents  Education  Self_Employed  \
# 0    1.735084  0.386931  1.356769    0.749143   0.543607       0.392026
# 1    1.729407  0.386931  0.702814    0.258432   0.543607       0.392026
# 2    1.723729  0.386931  0.702814    0.749143   0.543607       2.550853
# 3    1.718052  0.386931  0.702814    0.749143   1.839565       0.392026
# 4    1.712374  0.386931  1.356769    0.749143   0.543607       0.392026
# ..        ...       ...       ...         ...        ...            ...
# 609  1.722528  1.995520  1.356769    0.749143   0.543607       0.392026
# 610  1.728205  0.386931  0.702814    2.273580   0.543607       0.392026
# 611  1.733883  0.386931  0.702814    0.258432   0.543607       0.392026
# 612  1.739560  0.386931  0.702814    1.266006   0.543607       0.392026
# 613  1.745238  1.995520  1.356769    0.749143   0.543607       2.550853
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Taking the threshold to be 3

print(np.where(z>3))
# Out:
# (array([ 10,  17,  27,  31,  55,  59,  60,  83,  88,  90, 102, 102, 109,
#        114, 119, 122, 126, 128, 130, 146, 152, 159, 161, 166, 179, 215,
#        218, 220, 226, 226, 227, 231, 233, 252, 254, 282, 291, 292, 300,
#        315, 319, 333, 335, 335, 336, 337, 353, 360, 380, 385, 398, 406,
#        414, 418, 419, 422, 426, 429, 443, 460, 460, 461, 479, 480, 483,
#        484, 496, 513, 527, 530, 531, 539, 544], dtype=int64), array([7, 8, 8, 7, 9, 9, 8, 9, 9, 9, 6, 9, 7, 9, 7, 6, 9, 9, 6, 9, 9, 7,
#        9, 9, 9, 9, 9, 9, 7, 9, 6, 6, 8, 9, 6, 9, 6, 8, 9, 8, 9, 6, 7, 8,
#        9, 9, 9, 9, 6, 9, 7, 9, 9, 9, 6, 9, 6, 6, 6, 7, 9, 8, 6, 8, 9, 9,
#        9, 6, 9, 9, 6, 9, 9], dtype=int64))

# %%
df=df[(z<3).all(axis=1)]

df
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0        0.0       1        0         0.0          0              0
# 1        1.0       1        1         1.0          0              0
# 2        2.0       1        1         0.0          0              1
# 3        3.0       1        1         0.0          1              0
# 4        4.0       1        0         0.0          0              0
# ..       ...     ...      ...         ...        ...            ...
# 608    608.0       1        1         0.0          0              0
# 609    609.0       0        0         0.0          0              0
# 611    611.0       1        1         1.0          0              0
# 612    612.0       1        1         2.0          0              0
# 613    613.0       0        0         0.0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %% [markdown]
# # The above are the preprossed data using zscore

# %%
x = df.drop('Loan_Status', axis = 1)

y = df['Loan_Status']

# %%
y.value_counts()
# Out:
# Loan_Status
# 1.0    332
# 0.0    147
# Name: count, dtype: int64

# %% [markdown]
# The above dependent Loan_Status are not balanced.

# %%
#Oversampling the data



from imblearn.over_sampling import SMOTE

SM = SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
#To check the value count of target column

y.value_counts()
# Out:
# Loan_Status
# 1.0    332
# 0.0    147
# Name: count, dtype: int64

# %%
y1.value_counts()
# Out:
# Loan_Status
# 1.0    332
# 0.0    332
# Name: count, dtype: int64

# %% [markdown]
# The above y1 value_count shows that the data is balanced as they are equal

# %% [markdown]
# # MODELLING

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

maxAccu = 0
maxRS = 0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.30, random_state =i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best accuracy is ', maxAccu, 'at random_state', maxRS)
# Out:
# Best accuracy is  0.91 at random_state 8

# %% [markdown]
# # From the above, the best random state is 91% accuracy at the random_state 8

# %% [markdown]
# # CHECKING FOR OTHER BEST ALGORITHM

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, roc_curve

# %% [markdown]
# # FOR RANDOMFORESTCLASSIFIER

# %%
RFC= RandomForestClassifier()

RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predRFC=RFC.predict(x_test)

# %%
print(accuracy_score(y_test,predRFC))

print(confusion_matrix(y_test, predRFC))

print(classification_report(y_test,predRFC ))
# Out:
# 0.805
# [[63 20]
#  [19 98]]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.76      0.76        83
#          1.0       0.83      0.84      0.83       117
#
#     accuracy                           0.81       200
#    macro avg       0.80      0.80      0.80       200
# weighted avg       0.80      0.81      0.80       200

# %% [markdown]
# # FOR LOGISTIC REGRESSION

# %%
LR=LogisticRegression()

LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predLR=LR.predict(x_test)

# %%
print(accuracy_score(y_test,predLR))

print(confusion_matrix(y_test,predLR))

print(classification_report(y_test,predLR))
# Out:
# 0.695
# [[50 33]
#  [28 89]]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.60      0.62        83
#          1.0       0.73      0.76      0.74       117
#
#     accuracy                           0.69       200
#    macro avg       0.69      0.68      0.68       200
# weighted avg       0.69      0.69      0.69       200

# %% [markdown]
# # FOR GRADIENT BOOSTING CLASSIFIER

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predGB=GB.predict(x_test)

# %%
print(accuracy_score(y_test,predGB))

print(confusion_matrix(y_test,predGB))

print(classification_report(y_test,predGB))
# Out:
# 0.81
# [[ 57  26]
#  [ 12 105]]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.69      0.75        83
#          1.0       0.80      0.90      0.85       117
#
#     accuracy                           0.81       200
#    macro avg       0.81      0.79      0.80       200
# weighted avg       0.81      0.81      0.81       200

# %% [markdown]
# # FOR ADABOOST CLASSIFIER

# %%
AD=AdaBoostClassifier()

AD.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
predAD=AD.predict(x_test)

# %%
print(accuracy_score(y_test,predAD))

print(confusion_matrix(y_test,predAD))

print(classification_report(y_test, predAD))
# Out:
# 0.755
# [[58 25]
#  [24 93]]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.70      0.70        83
#          1.0       0.79      0.79      0.79       117
#
#     accuracy                           0.76       200
#    macro avg       0.75      0.75      0.75       200
# weighted avg       0.75      0.76      0.75       200

# %% [markdown]
# # FROM THE ABOVE MODEL, THE BEST MODEL WITH HIGHEST ACCURACY IS THE GRADIENTBOOSTINGCLASSIFIER

# %% [markdown]
# FOR THE CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Checking for cross validation for GradientBoostingClassifier

# %%
score=cross_val_score(GB,x1,y1)

# %%
print(score)

print(score.mean())

print('DIFFERENCE BETWEEN:',(accuracy_score(y_test,predGB)-score.mean()))
# Out:
# [0.38345865 0.27819549 0.67669173 0.5112782  0.46212121]
# 0.4623490544543176
# DIFFERENCE BETWEEN: 0.34765094554568243

# %%
#CHECKING FOR RANDOM FOREST CLASSIFIER

score=cross_val_score(RFC,x1,y1)

print(score)

print(score.mean())

print('DIFFERENCE BETWEEN:',(accuracy_score(y_test,predRFC)-score.mean()))
# Out:
# [0.37593985 0.40601504 0.84962406 0.7443609  0.47727273]
# 0.5706425153793575
# DIFFERENCE BETWEEN: 0.23435748462064254

# %%
#CHECKING FOR LOGISTIC REGRESSION


score=cross_val_score(LR,x1,y1)

print(score)

print(score.mean())

print('DIFFERENCE BETWEEN:',(accuracy_score(y_test,predLR)-score.mean()))
# Out:
# [0.66165414 0.62406015 0.69172932 0.76691729 0.73484848]
# 0.6958418774208248
# DIFFERENCE BETWEEN: -0.0008418774208248658

# %%
#CHECKING FOR ADABOOSTCLASSIFIER


score=cross_val_score(AD,x1,y1)

print(score)

print(score.mean())

print('DIFFERENCE BETWEEN:',(accuracy_score(y_test,predAD)-score.mean()))
# Out:
# [0.33082707 0.28571429 0.62406015 0.54135338 0.42424242]
# 0.4412394622920939
# DIFFERENCE BETWEEN: 0.31376053770790613

# %% [markdown]
# # IN CONCLUSION, THE BEST MODEL IS LOGISTIC REGRESSION. THIS IS BECAUSE THE DIFFERECE BETWEEN THE ACCURACY SCORE AND CROSS VALIDATION IN THIS LOGISTIC REGRESSION GAVE THE LEAST SCORE

# %% [markdown]
# # To save the model

# %%
import joblib

# %%
joblib.dump(LR,'Applicant_approved_Loan_Status.PKI')
# Out:
# ['Applicant_approved_Loan_Status.PKI']
