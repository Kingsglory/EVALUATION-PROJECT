# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('rainfall.csv')

df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Date',
#  'Location',
#  'MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
df.isnull().sum()

#The dataset show that the rainfall dataset has  many missing value but no missing value on the Date and Location
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
df.info()


#The information shows that the data has 8425 entries, 23 columns, dtype of only float and object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
sns.heatmap(df.isnull(), cmap='cool_r')


#There is presence of missing value
# Out:
# <Axes: >

# %%
#To check for value count



for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Date
# 2011-01-31    5
# 2011-05-08    5
# 2011-05-21    5
# 2011-05-20    5
# 2011-05-19    5
#              ..
# 2013-01-28    1
# 2013-01-29    1
# 2013-01-30    1
# 2013-01-31    1
# 2013-06-08    1
# Name: count, Length: 3004, dtype: int64
#
#
# Location
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: count, dtype: int64
#
#
# MinTemp
#  12.0    74
#  13.2    71
#  13.8    69
#  12.7    68
#  16.4    67
#          ..
#  0.3      1
#  28.3     1
# -1.1      1
# -1.4      1
#  26.0     1
# Name: count, Length: 285, dtype: int64
#
#
# MaxTemp
# 19.0    87
# 23.8    75
# 19.8    74
# 25.0    71
# 22.0    68
#         ..
# 11.2     1
# 43.1     1
# 42.7     1
# 42.9     1
# 43.5     1
# Name: count, Length: 331, dtype: int64
#
#
# Rainfall
# ...

# %%
df.dtypes

#this contain two datatype which are the object and float.
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df


#This table shows the correspondent row and columns withe the data they contain
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %% [markdown]
# # TO EXPLAIN SOME POSSIBLE DATA VISUALIZATION

# %%
RFt=sns.countplot(y='RainTomorrow', data=df)

print(df['RainTomorrow'].value_counts())


#The graph shows that the ossibility of rainfall tomorrow is 1991 and the forcast that there will be no rainfall shows 6195. 
#Therefore the likelyhood of rainfall is small.
# Out:
# RainTomorrow
# No     6195
# Yes    1991
# Name: count, dtype: int64

# %%
RFtoday=sns.countplot(x='RainToday',data=df)

print(df['RainToday'].value_counts())


#The tendency that the rainfall will not occure today is very high which is about three time when compare to the yes
# Out:
# RainToday
# No     6195
# Yes    1990
# Name: count, dtype: int64

# %%
sns.catplot(y='RainToday',hue='RainTomorrow',palette='cool_r',kind='count',data=df)

plt.show()

#comparing the level of RainTomorrow and RainToday. It shows that the tendency of rain falling today is almost equal

# %%
Cl3=sns.countplot(x='Cloud3pm', data=df)

print(df['Cloud3pm'].value_counts())

#At 3pm, the cloud is high at point 7 while at point 0.0 shows the least
# Out:
# Cloud3pm
# 7.0    1294
# 1.0    1077
# 8.0     863
# 6.0     597
# 5.0     522
# 2.0     508
# 3.0     411
# 4.0     351
# 0.0     347
# Name: count, dtype: int64

# %%
RFtoday=sns.countplot(x='Cloud9am',data=df)

print(df['Cloud9am'].value_counts())


#Unlike the cloud at 3pm which was least at 0.0, the cloud at 4.0 shows the least while 7.0 shows the highest cloud at 9am.
# Out:
# Cloud9am
# 7.0    1418
# 1.0    1038
# 8.0    1015
# 0.0     554
# 6.0     551
# 5.0     414
# 3.0     384
# 2.0     357
# 4.0     273
# Name: count, dtype: int64

# %%
sns.catplot(y='Cloud3pm',hue='Cloud9am',palette='cool_r',kind='count',data=df)

plt.show()

# %%
Lo=sns.countplot(y='Location',data=df)


print(df['Location'].value_counts())


#The melbourne has the highest tendecy of of data collection while Uluru shows the least.
# Out:
# Location
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: count, dtype: int64

# %%
sns.distplot(df['MaxTemp'], color = 'm', kde_kws = {'shade':True}, hist = False)

plt.show()

#The maximum temperature occure between 20 and 30 based on the distplot.

# %%
sns.distplot(df['MinTemp'], color = 'm', kde_kws = {'shade':True}, hist = True)

plt.show()

#The peak minimum temperature is between 10 and 15.

# %%
sns.distplot(df['Rainfall'], color = 'm', kde_kws = {'shade':True}, hist = False)

plt.show()

#Most of the rain occure at 0.0 value and has maximum density.

# %%
sns.distplot(df['Evaporation'], color = 'm', kde_kws = {'shade':True}, hist = False)

plt.show()

# %%
sns.distplot(df['Sunshine'], color = 'm', kde_kws = {'shade':True}, hist = False)

plt.show()

#There more sunshine at 10.0

# %%
sns.countplot(y='WindGustDir',data=df)

print(df['WindGustDir'].value_counts())


#The windDirection is more towards the N. and lowest at NNW.
# Out:
# WindGustDir
# N      713
# SSE    578
# S      577
# SW     572
# E      557
# WNW    531
# W      507
# WSW    504
# SE     484
# ENE    415
# SSW    396
# NW     383
# NE     353
# NNE    343
# ESE    302
# NNW    219
# Name: count, dtype: int64

# %%
sns.distplot(df['WindGustSpeed'], color='m', kde_kws={'shade':True}, hist=False)


plt.show()

#The windgustspeed is more at 40.

# %%
sns.distplot(df['Pressure9am'], color='m', kde_kws={'shade':True}, hist=False)


plt.show()

#AT 9am, there was more at 1020.

# %%
sns.distplot(df['Pressure3pm'], color='m', kde_kws={'shade':True}, hist=False)


plt.show()

#There was presence of maximum pressure between 1010 and 1020.

# %%
sns.distplot(df['Temp9am'], color='m', kde_kws={'shade':True}, hist=False)


plt.show()

#At 9am, there was a little decrease in temperature at the peak.

# %%
sns.distplot(df['Temp3pm'], color='m', kde_kws={'shade':True}, hist=False)


plt.show()

#At 3pm, there was more temperature at 15 and 25.

# %%
sns.distplot(df['Humidity3pm'], color='m',kde_kws={'shade':True}, hist=False)


#at 3pm humidity was more between 40 and 60.
# Out:
# <Axes: xlabel='Humidity3pm', ylabel='Density'>

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.head(60)
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5   2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6   2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7   2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8   2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9   2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10  2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# ...

# %%
df.sample(8400)
# Out:
#             Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 3156  2016-09-18   Williamtown     13.5     17.7       0.0          NaN
# 2721  2015-06-05       Penrith      4.5     16.0       1.6          NaN
# 5156  2011-08-02     Melbourne     11.7     20.2       0.4          3.4
# 2383  2014-07-02       Penrith      2.1     19.1       0.0          NaN
# 8225  2012-06-03        Darwin     21.8     31.8       0.0          5.0
# ...          ...           ...      ...      ...       ...          ...
# 1359  2010-06-05  CoffsHarbour     14.9     21.7       1.8          2.4
# 2474  2014-10-01       Penrith     15.2     22.2       0.0          NaN
# 5776  2010-12-24     Melbourne     11.5     23.5       0.0          6.4
# 1672  2013-11-10     Newcastle     15.0     22.8       0.0          NaN
# 825   2011-03-06        Albury      9.6     25.3       0.0          NaN
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
#checking for categorical columns

categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical columns:",categorical_col)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
#
#
# Numerical columns: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
df.head(2)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
#
#    RainTomorrow
# 0            No
# 1            No
#
# [2 rows x 23 columns]

# %%
print('The mean value of MinTemp is:', df['MinTemp'].mean())
print('The mean value of MaxTemp is:', df['MaxTemp'].mean())

print('The mean value of Rainfall is:', df['Rainfall'].mean())
print('The mean value of Evaporation is:', df['Evaporation'].mean())

print('The mean value of Sunshine is:', df['Sunshine'].mean())

print('The mean value of WindGustSpeed is:', df['WindGustSpeed'].mean())

print('The mean value of WindSpeed9am is:', df['WindSpeed9am'].mean())

print('The mean value of WindSpeed3pm is:', df['WindSpeed3pm'].mean())

print('The mean value of Humidity9am is:', df['Humidity9am'].mean())

print('The mean value of Humidity3pm is:', df['Humidity3pm'].mean())

print('The mean value of Pressure9am is:', df['Pressure9am'].mean())

print('The mean value of Pressure3pm is:', df['Pressure3pm'].mean())

print('The mean value of Cloud9am is:', df['Cloud9am'].mean())

print('The mean value of Cloud3pm is:', df['Cloud3pm'].mean())

print('The mean value of Temp9am is:', df['Temp9am'].mean())

print('The mean value of Temp3pm is:', df['Temp3pm'].mean())
# Out:
# The mean value of MinTemp is: 13.193305389221557
# The mean value of MaxTemp is: 23.85997609085475
# The mean value of Rainfall is: 2.8059132559560167
# The mean value of Evaporation is: 5.38939548137594
# The mean value of Sunshine is: 7.632204919882645
# The mean value of WindGustSpeed is: 40.174468657519505
# The mean value of WindSpeed9am is: 13.847646424721523
# The mean value of WindSpeed3pm is: 18.533661937965856
# The mean value of Humidity9am is: 67.82249581639971
# The mean value of Humidity3pm is: 51.2497897392767
# The mean value of Pressure9am is: 1017.640233277122
# The mean value of Pressure3pm is: 1015.2360747926332
# The mean value of Cloud9am is: 4.566622251832112
# The mean value of Cloud3pm is: 4.5031825795644895
# The mean value of Temp9am is: 17.762014577607836
# The mean value of Temp3pm is: 22.442934325849443

# %%
df["MinTemp"]=df["MinTemp"].fillna(df["MinTemp"].mean())
df["MaxTemp"]=df["MaxTemp"].fillna(df["MaxTemp"].mean())
df["Rainfall"]=df["Rainfall"].fillna(df["Rainfall"].mean())
df["Evaporation"]=df["Evaporation"].fillna(df["Evaporation"].mean())
df["Sunshine"]=df["Sunshine"].fillna(df["Sunshine"].mean())
df["WindGustSpeed"]=df["WindGustSpeed"].fillna(df["WindGustSpeed"].mean())

df["WindSpeed9am"]=df["WindSpeed9am"].fillna(df["WindSpeed9am"].mean())
df["WindSpeed3pm"]=df["WindSpeed3pm"].fillna(df["WindSpeed3pm"].mean())

df["Humidity9am"]=df["Humidity9am"].fillna(df["Humidity9am"].mean())
df["Humidity3pm"]=df["Humidity3pm"].fillna(df["Humidity3pm"].mean())

df["Pressure9am"]=df["Pressure9am"].fillna(df["Pressure9am"].mean())
df["Pressure3pm"]=df["Pressure3pm"].fillna(df["Pressure3pm"].mean())

df["Cloud9am"]=df["Cloud9am"].fillna(df["Cloud9am"].mean())
df["Cloud3pm"]=df["Cloud3pm"].fillna(df["Cloud3pm"].mean())

df["Temp9am"]=df["Temp9am"].fillna(df["Temp9am"].mean())
df["Temp3pm"]=df["Temp3pm"].fillna(df["Temp3pm"].mean())

# %%
df.isnull().sum()

#All the missing data in the numerical columns have been filled with mean values.
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir      991
# WindGustSpeed      0
# WindDir9am       829
# WindDir3pm       308
# WindSpeed9am       0
# WindSpeed3pm       0
# Humidity9am        0
# Humidity3pm        0
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday        240
# RainTomorrow     239
# dtype: int64

# %%
df
# Out:
#             Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0     2008-12-01   Albury     13.4  22.900000       0.6     5.389395
# 1     2008-12-02   Albury      7.4  25.100000       0.0     5.389395
# 2     2008-12-03   Albury     12.9  25.700000       0.0     5.389395
# 3     2008-12-04   Albury      9.2  28.000000       0.0     5.389395
# 4     2008-12-05   Albury     17.5  32.300000       1.0     5.389395
# ...          ...      ...      ...        ...       ...          ...
# 8420  2017-06-21    Uluru      2.8  23.400000       0.0     5.389395
# 8421  2017-06-22    Uluru      3.6  25.300000       0.0     5.389395
# 8422  2017-06-23    Uluru      5.4  26.900000       0.0     5.389395
# 8423  2017-06-24    Uluru      7.8  27.000000       0.0     5.389395
# 8424  2017-06-25    Uluru     14.9  23.859976       0.0     5.389395
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
print('min.Date=',df.Date.min())

print('max.Date=',df.Date.max())
# Out:
# min.Date= 2008-12-01
# max.Date= 2017-06-25

# %%
#Converting the datatype of date from object to datetime.

df['Date']=pd.to_datetime(df['Date'],format='%Y-%M-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   datetime64[ns]
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
df
# Out:
#                     Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0    2008-01-01 00:12:00   Albury     13.4  22.900000       0.6     5.389395
# 1    2008-01-02 00:12:00   Albury      7.4  25.100000       0.0     5.389395
# 2    2008-01-03 00:12:00   Albury     12.9  25.700000       0.0     5.389395
# 3    2008-01-04 00:12:00   Albury      9.2  28.000000       0.0     5.389395
# 4    2008-01-05 00:12:00   Albury     17.5  32.300000       1.0     5.389395
# ...                  ...      ...      ...        ...       ...          ...
# 8420 2017-01-21 00:06:00    Uluru      2.8  23.400000       0.0     5.389395
# 8421 2017-01-22 00:06:00    Uluru      3.6  25.300000       0.0     5.389395
# 8422 2017-01-23 00:06:00    Uluru      5.4  26.900000       0.0     5.389395
# 8423 2017-01-24 00:06:00    Uluru      7.8  27.000000       0.0     5.389395
# 8424 2017-01-25 00:06:00    Uluru     14.9  23.859976       0.0     5.389395
#
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df
#The was set as the index number successfully
# Out:
#                     Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# Date
# 2008-01-01 00:12:00   Albury     13.4  22.900000       0.6     5.389395
# 2008-01-02 00:12:00   Albury      7.4  25.100000       0.0     5.389395
# 2008-01-03 00:12:00   Albury     12.9  25.700000       0.0     5.389395
# 2008-01-04 00:12:00   Albury      9.2  28.000000       0.0     5.389395
# 2008-01-05 00:12:00   Albury     17.5  32.300000       1.0     5.389395
# ...                      ...      ...        ...       ...          ...
# 2017-01-21 00:06:00    Uluru      2.8  23.400000       0.0     5.389395
# 2017-01-22 00:06:00    Uluru      3.6  25.300000       0.0     5.389395
# 2017-01-23 00:06:00    Uluru      5.4  26.900000       0.0     5.389395
# 2017-01-24 00:06:00    Uluru      7.8  27.000000       0.0     5.389395
# 2017-01-25 00:06:00    Uluru     14.9  23.859976       0.0     5.389395
#
#                      Sunshine WindGustDir  WindGustSpeed WindDir9am  \
# Date
# ...

# %%
df.nunique().to_frame('EXACT UNIQUE VALUES OF THE RAINFALL')
# Out:
#                EXACT UNIQUE VALUES OF THE RAINFALL
# Location                                        12
# MinTemp                                        286
# MaxTemp                                        332
# Rainfall                                       251
# Evaporation                                    117
# Sunshine                                       141
# WindGustDir                                     16
# WindGustSpeed                                   53
# WindDir9am                                      16
# WindDir3pm                                      16
# WindSpeed9am                                    35
# WindSpeed3pm                                    36
# Humidity9am                                     91
# Humidity3pm                                     95
# Pressure9am                                    385
# Pressure3pm                                    375
# Cloud9am                                        10
# ...

# %%
df.isnull().sum()
# Out:
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir      991
# WindGustSpeed      0
# WindDir9am       829
# WindDir3pm       308
# WindSpeed9am       0
# WindSpeed3pm       0
# Humidity9am        0
# Humidity3pm        0
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday        240
# RainTomorrow     239
# dtype: int64

# %%
#checking for categorical columns

categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical columns:",categorical_col)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
#
#
# Numerical columns: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Location']=le.fit_transform(df['Location'])

df['WindGustDir']=le.fit_transform(df['WindGustDir'])

df['WindDir9am']=le.fit_transform(df['WindDir9am'])

df['WindDir3pm']=le.fit_transform(df['WindDir3pm'])

df['RainToday']=le.fit_transform(df['RainToday'])

df['RainTomorrow']=le.fit_transform(df['RainTomorrow'])

# %%
df
# Out:
#                      Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# Date
# 2008-01-01 00:12:00         1     13.4  22.900000       0.6     5.389395
# 2008-01-02 00:12:00         1      7.4  25.100000       0.0     5.389395
# 2008-01-03 00:12:00         1     12.9  25.700000       0.0     5.389395
# 2008-01-04 00:12:00         1      9.2  28.000000       0.0     5.389395
# 2008-01-05 00:12:00         1     17.5  32.300000       1.0     5.389395
# ...                       ...      ...        ...       ...          ...
# 2017-01-21 00:06:00         9      2.8  23.400000       0.0     5.389395
# 2017-01-22 00:06:00         9      3.6  25.300000       0.0     5.389395
# 2017-01-23 00:06:00         9      5.4  26.900000       0.0     5.389395
# 2017-01-24 00:06:00         9      7.8  27.000000       0.0     5.389395
# 2017-01-25 00:06:00         9     14.9  23.859976       0.0     5.389395
#
#                      Sunshine  WindGustDir  WindGustSpeed  WindDir9am  \
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8425 entries, 2008-01-01 00:12:00 to 2017-01-25 00:06:00
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       8425 non-null   int32
#  1   MinTemp        8425 non-null   float64
#  2   MaxTemp        8425 non-null   float64
#  3   Rainfall       8425 non-null   float64
#  4   Evaporation    8425 non-null   float64
#  5   Sunshine       8425 non-null   float64
#  6   WindGustDir    8425 non-null   int32
#  7   WindGustSpeed  8425 non-null   float64
#  8   WindDir9am     8425 non-null   int32
#  9   WindDir3pm     8425 non-null   int32
#  10  WindSpeed9am   8425 non-null   float64
#  11  WindSpeed3pm   8425 non-null   float64
#  12  Humidity9am    8425 non-null   float64
#  13  Humidity3pm    8425 non-null   float64
#  14  Pressure9am    8425 non-null   float64
#  15  Pressure3pm    8425 non-null   float64
# ...

# %%
df['Location']=df['Location'].astype(float)

df['WindGustDir']=df['WindGustDir'].astype(float)

df['WindDir9am']=df['WindDir9am'].astype(float)

df['WindDir3pm']=df['WindDir3pm'].astype(float)

df['RainToday']=df['RainToday'].astype(float)

df['RainTomorrow']=df['RainTomorrow'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8425 entries, 2008-01-01 00:12:00 to 2017-01-25 00:06:00
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       8425 non-null   float64
#  1   MinTemp        8425 non-null   float64
#  2   MaxTemp        8425 non-null   float64
#  3   Rainfall       8425 non-null   float64
#  4   Evaporation    8425 non-null   float64
#  5   Sunshine       8425 non-null   float64
#  6   WindGustDir    8425 non-null   float64
#  7   WindGustSpeed  8425 non-null   float64
#  8   WindDir9am     8425 non-null   float64
#  9   WindDir3pm     8425 non-null   float64
#  10  WindSpeed9am   8425 non-null   float64
#  11  WindSpeed3pm   8425 non-null   float64
#  12  Humidity9am    8425 non-null   float64
#  13  Humidity3pm    8425 non-null   float64
#  14  Pressure9am    8425 non-null   float64
#  15  Pressure3pm    8425 non-null   float64
# ...

# %%
df
# Out:
#                      Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# Date
# 2008-01-01 00:12:00       1.0     13.4  22.900000       0.6     5.389395
# 2008-01-02 00:12:00       1.0      7.4  25.100000       0.0     5.389395
# 2008-01-03 00:12:00       1.0     12.9  25.700000       0.0     5.389395
# 2008-01-04 00:12:00       1.0      9.2  28.000000       0.0     5.389395
# 2008-01-05 00:12:00       1.0     17.5  32.300000       1.0     5.389395
# ...                       ...      ...        ...       ...          ...
# 2017-01-21 00:06:00       9.0      2.8  23.400000       0.0     5.389395
# 2017-01-22 00:06:00       9.0      3.6  25.300000       0.0     5.389395
# 2017-01-23 00:06:00       9.0      5.4  26.900000       0.0     5.389395
# 2017-01-24 00:06:00       9.0      7.8  27.000000       0.0     5.389395
# 2017-01-25 00:06:00       9.0     14.9  23.859976       0.0     5.389395
#
#                      Sunshine  WindGustDir  WindGustSpeed  WindDir9am  \
# Date
# ...

# %%
df.isnull().sum()

#There is no presence of missing value
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
#There is is no NAN value

sns.heatmap(df.isnull(),cmap='cool_r')
# Out:
# <Axes: ylabel='Date'>

# %%
df.describe()
# Out:
#           Location      MinTemp      MaxTemp     Rainfall  Evaporation  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean      5.793591    13.193305    23.859976     2.805913     5.389395
# std       3.162654     5.379488     6.114516    10.309308     3.852004
# min       0.000000    -2.000000     8.200000     0.000000     0.000000
# 25%       3.000000     9.300000    19.300000     0.000000     4.000000
# 50%       6.000000    13.200000    23.300000     0.000000     5.389395
# 75%       8.000000    17.300000    28.000000     1.400000     5.389395
# max      11.000000    28.500000    45.500000   371.000000   145.000000
#
#           Sunshine  WindGustDir  WindGustSpeed   WindDir9am   WindDir3pm  ...  \
# count  8425.000000  8425.000000    8425.000000  8425.000000  8425.000000  ...
# mean      7.632205     8.746944      40.174469     8.546588     8.066350  ...
# std       2.825451     5.172665      13.776101     5.012591     4.686287  ...
# ...

# %%
df.corr()
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location       1.000000  0.116531  0.064268  0.007693     0.143519  0.057817
# MinTemp        0.116531  1.000000  0.717522  0.087684     0.254965  0.056184
# MaxTemp        0.064268  0.717522  1.000000 -0.087451     0.322405  0.378403
# Rainfall       0.007693  0.087684 -0.087451  1.000000     0.023517 -0.169432
# Evaporation    0.143519  0.254965  0.322405  0.023517     1.000000  0.226001
# Sunshine       0.057817  0.056184  0.378403 -0.169432     0.226001  1.000000
# WindGustDir    0.005877 -0.139270 -0.201870  0.056031    -0.045612 -0.090364
# WindGustSpeed  0.231396  0.230058  0.139998  0.086000     0.136371 -0.013778
# WindDir9am    -0.077362 -0.144183 -0.246027  0.077539    -0.040679 -0.078326
# WindDir3pm    -0.024786 -0.156968 -0.189354  0.039913    -0.046021 -0.069322
# WindSpeed9am   0.221378  0.136872  0.013314  0.050631     0.104294 -0.018069
# ...

# %%
plt.figure(figsize = (20,15))

sns.heatmap(df.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
plt.figure(figsize=(22, 7))

df.corr()['RainTomorrow'].sort_values(ascending = False).drop(['RainTomorrow']).plot(kind='bar',color='m')

plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title('Correlation between the label and feature using barplot', fontsize = 20)

plt.show()

#THERE IS HIGH CORRELATION AT THE BOTH ENDING PATH OF THE GRAPH BUT WINDDIR3am,WINDDIR9AM AND TEMP9AM SHOWS LOW CORRELATIONS

# %%
df
# Out:
#                      Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# Date
# 2008-01-01 00:12:00       1.0     13.4  22.900000       0.6     5.389395
# 2008-01-02 00:12:00       1.0      7.4  25.100000       0.0     5.389395
# 2008-01-03 00:12:00       1.0     12.9  25.700000       0.0     5.389395
# 2008-01-04 00:12:00       1.0      9.2  28.000000       0.0     5.389395
# 2008-01-05 00:12:00       1.0     17.5  32.300000       1.0     5.389395
# ...                       ...      ...        ...       ...          ...
# 2017-01-21 00:06:00       9.0      2.8  23.400000       0.0     5.389395
# 2017-01-22 00:06:00       9.0      3.6  25.300000       0.0     5.389395
# 2017-01-23 00:06:00       9.0      5.4  26.900000       0.0     5.389395
# 2017-01-24 00:06:00       9.0      7.8  27.000000       0.0     5.389395
# 2017-01-25 00:06:00       9.0     14.9  23.859976       0.0     5.389395
#
#                      Sunshine  WindGustDir  WindGustSpeed  WindDir9am  \
# Date
# ...

# %%
df.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))

#THE BOX PLOT SHOWS THERE IS PRESENCE OF OUTLIERS.
# Out:
# Location            Axes(0.125,0.712609;0.110714x0.167391)
# MinTemp          Axes(0.257857,0.712609;0.110714x0.167391)
# MaxTemp          Axes(0.390714,0.712609;0.110714x0.167391)
# Rainfall         Axes(0.523571,0.712609;0.110714x0.167391)
# Evaporation      Axes(0.656429,0.712609;0.110714x0.167391)
# Sunshine         Axes(0.789286,0.712609;0.110714x0.167391)
# WindGustDir         Axes(0.125,0.511739;0.110714x0.167391)
# WindGustSpeed    Axes(0.257857,0.511739;0.110714x0.167391)
# WindDir9am       Axes(0.390714,0.511739;0.110714x0.167391)
# WindDir3pm       Axes(0.523571,0.511739;0.110714x0.167391)
# WindSpeed9am     Axes(0.656429,0.511739;0.110714x0.167391)
# WindSpeed3pm     Axes(0.789286,0.511739;0.110714x0.167391)
# Humidity9am          Axes(0.125,0.31087;0.110714x0.167391)
# Humidity3pm       Axes(0.257857,0.31087;0.110714x0.167391)
# Pressure9am       Axes(0.390714,0.31087;0.110714x0.167391)
# Pressure3pm       Axes(0.523571,0.31087;0.110714x0.167391)
# ...

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
z=np.abs(zscore(df))

z
# Out:
#                      Location   MinTemp       MaxTemp  Rainfall   Evaporation  \
# Date
# 2008-01-01 00:12:00  1.515776  0.038425  1.570089e-01  0.213986  2.305893e-16
# 2008-01-02 00:12:00  1.515776  1.076989  2.028121e-01  0.272189  2.305893e-16
# 2008-01-03 00:12:00  1.515776  0.054526  3.009450e-01  0.272189  2.305893e-16
# 2008-01-04 00:12:00  1.515776  0.742365  6.771214e-01  0.272189  2.305893e-16
# 2008-01-05 00:12:00  1.515776  0.800625  1.380408e+00  0.175183  2.305893e-16
# ...                       ...       ...           ...       ...           ...
# 2017-01-21 00:06:00  1.013895  1.932140  7.523137e-02  0.272189  2.305893e-16
# 2017-01-22 00:06:00  1.013895  1.783418  2.355231e-01  0.272189  2.305893e-16
# 2017-01-23 00:06:00  1.013895  1.448794  4.972110e-01  0.272189  2.305893e-16
# 2017-01-24 00:06:00  1.013895  1.002628  5.135665e-01  0.272189  2.305893e-16
# 2017-01-25 00:06:00  1.013895  0.317279  5.810639e-16  0.272189  2.305893e-16
#
# ...

# %%
#Taking the threshold to be 3

print(np.where(z>3))
# Out:
# (array([  12,   12,   14, ..., 8145, 8185, 8424], dtype=int64), array([14, 15, 21, ...,  7,  3, 21], dtype=int64))

# %%
df=df[(z<3).all(axis=1)]

df
# Out:
#                      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# Date
# 2008-01-01 00:12:00       1.0     13.4     22.9       0.6     5.389395
# 2008-01-02 00:12:00       1.0      7.4     25.1       0.0     5.389395
# 2008-01-03 00:12:00       1.0     12.9     25.7       0.0     5.389395
# 2008-01-04 00:12:00       1.0      9.2     28.0       0.0     5.389395
# 2008-01-05 00:12:00       1.0     17.5     32.3       1.0     5.389395
# ...                       ...      ...      ...       ...          ...
# 2017-01-20 00:06:00       9.0      3.5     21.8       0.0     5.389395
# 2017-01-21 00:06:00       9.0      2.8     23.4       0.0     5.389395
# 2017-01-22 00:06:00       9.0      3.6     25.3       0.0     5.389395
# 2017-01-23 00:06:00       9.0      5.4     26.9       0.0     5.389395
# 2017-01-24 00:06:00       9.0      7.8     27.0       0.0     5.389395
#
#                      Sunshine  WindGustDir  WindGustSpeed  WindDir9am  \
# Date
# ...

# %%
x = df.drop('RainTomorrow', axis = 1)

y = df['RainTomorrow']

# %%
y.value_counts()

#the value value are not balanced
# Out:
# RainTomorrow
# 0.0    5901
# 1.0    1757
# Name: count, dtype: int64

# %%
#Oversampling the data



from imblearn.over_sampling import SMOTE

SM = SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
#To check the value count of target column

y.value_counts()
# Out:
# RainTomorrow
# 0.0    5901
# 1.0    1757
# Name: count, dtype: int64

# %%
y1.value_counts()

#the data was balanced using SMOTE
# Out:
# RainTomorrow
# 0.0    5901
# 1.0    5901
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
maxAccu = 0
maxRS = 0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.30, random_state =i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best accuracy is ', maxAccu, 'at random_state', maxRS)
# Out:
# Best accuracy is  0.9398475007060153 at random_state 142

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, roc_curve

# %%
RFC= RandomForestClassifier()

RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predRFC=RFC.predict(x_test)

# %%
print(accuracy_score(y_test,predRFC))

print(confusion_matrix(y_test, predRFC))

print(classification_report(y_test,predRFC ))
# Out:
# 0.9212086981078791
# [[1666  133]
#  [ 146 1596]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.93      0.92      1799
#          1.0       0.92      0.92      0.92      1742
#
#     accuracy                           0.92      3541
#    macro avg       0.92      0.92      0.92      3541
# weighted avg       0.92      0.92      0.92      3541

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predGB=GB.predict(x_test)

# %%
print(accuracy_score(y_test,predGB))

print(confusion_matrix(y_test,predGB))

print(classification_report(y_test,predGB))
# Out:
# 0.8599265744140073
# [[1587  212]
#  [ 284 1458]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.88      0.86      1799
#          1.0       0.87      0.84      0.85      1742
#
#     accuracy                           0.86      3541
#    macro avg       0.86      0.86      0.86      3541
# weighted avg       0.86      0.86      0.86      3541

# %%
#FROM THE ABOVE DIFFERENT MODEL USED, RANDOMFORESTCLASSIFIER GAVE THE HIGHEST ACCURACY SCORE OF 92%
#THIS SHOWS THAT THE PRECISION THAT THERE WILL BE RAINFALL TOMORROW IS 92%.
#IT SHOWS THAT THERE IS HIGHER TENDENCY THAT IT WILL RAIN TOMORROW.

#THERE WILL BE HEAVY RAINFALL OF 86% IN WEIGHT.

# %%
import joblib

# %%
joblib.dump(RFC,'Rainfall_Project.PKI')
# Out:
# ['Rainfall_Project.PKI']
