# %%
import pandas as pd

# %%
df=pd.read_csv('globalpowerplantAUS.csv')

df
# Out:
#     country country_long                                 name   gppd_idnr  \
# 0       AUS    Australia                     Adelaide Airport  AUS0000433
# 1       AUS    Australia                 Adelaide Showgrounds  AUS0000432
# 2       AUS    Australia                     Albany Wind Farm  AUS0000065
# 3       AUS    Australia                Alice Springs Airport  AUS0000469
# 4       AUS    Australia                         Amcor Gawler  AUS0000231
# ..      ...          ...                                  ...         ...
# 507     AUS    Australia                           Yarrawonga  AUS0000101
# 508     AUS    Australia                               Yarwun  AUS0000173
# 509     AUS    Australia                             Yuendumu  AUS0000465
# 510     AUS    Australia                               Yulara  AUS0000257
# 511     AUS    Australia  Yurralyi Maya (Karratha Seven Mile)  AUS0000218
#
#      capacity_mw  latitude  longitude primary_fuel  other_fuel1  other_fuel2  \
# ...

# %%
df.shape
# Out:
# (512, 27)

# %% [markdown]
# # THE GLOBAL POWER PLANT FOR AUS, HAS 512 ROWS AND 27 COLUMNS

# %%
df1=pd.read_csv('database_IND.csv')

df1
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df1.shape
# Out:
# (907, 27)

# %% [markdown]
# # THE DATA BASE FOR IND HAS 907 ROWS AND 27 COLUMNS

# %%
df2=pd.read_csv('database_USA.csv')

df2
# Out:
#       country              country_long                            name  \
# 0         USA  United States of America  10 Briggs Solar NG  LLC (East)
# 1         USA  United States of America      100 Brook Hill Drive Solar
# 2         USA  United States of America      1001 Ebenezer Church Solar
# 3         USA  United States of America             1008 Matthews Solar
# 4         USA  United States of America               1009 Yadkin Solar
# ...       ...                       ...                             ...
# 11874     USA  United States of America        Zotos International WPGF
# 11875     USA  United States of America   Zumbro Community Solar Garden
# 11876     USA  United States of America             Zumbro Solar Garden
# 11877     USA  United States of America                            Zuni
# 11878     USA  United States of America             eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
df2.shape
# Out:
# (11879, 27)

# %% [markdown]
# # the data base for USA has 11879 rows and 27 columns

# %% [markdown]
# # NOTE CONCAT WILL BE USE TO JOIN THE THREE TABLES BECAUSE THE COLUMNS OF THE THREE TABLES ARE THE SAME

# %%
import pandas as pd

import numpy as np

# %%
dfnew=pd.concat([df,df1,df2],ignore_index=True)

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
dfnew.shape
# Out:
# (13298, 27)

# %% [markdown]
# # The new data after combination contains 13298 rows and 27 columns

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
#To see the first five data

dfnew.head()
# Out:
#   country country_long                   name   gppd_idnr  capacity_mw  \
# 0     AUS    Australia       Adelaide Airport  AUS0000433         0.11
# 1     AUS    Australia   Adelaide Showgrounds  AUS0000432         1.00
# 2     AUS    Australia       Albany Wind Farm  AUS0000065        21.60
# 3     AUS    Australia  Alice Springs Airport  AUS0000469         0.24
# 4     AUS    Australia           Amcor Gawler  AUS0000231         4.00
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0  -34.9387   138.5377        Solar         NaN         NaN  ...
# 1  -34.9453   138.5882        Solar         NaN         NaN  ...
# 2  -35.0641   117.7977         Wind         NaN         NaN  ...
# 3  -23.7966   133.8971        Solar         NaN         NaN  ...
# 4  -34.5509   138.7659          Oil         NaN         NaN  ...
#
#   year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                2019.0                  NaN                 NaN
# ...

# %%
#for the last five data

dfnew.tail()
# Out:
#       country              country_long                           name  \
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 13293  USA0057648          3.4   42.8869   -76.9683         Wind         NaN
# 13294  USA0061574          1.0   44.3195   -92.6703        Solar         NaN
# 13295  USA0063426          0.0   44.0460   -92.7600          NaN         NaN
# 13296  USA0000478          0.0   39.7373  -105.0170          NaN         NaN
# 13297  USA0059281          9.8   40.5606  -112.0478          Gas         NaN
#
#       other_fuel2  ... year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
dfnew.sample()
# Out:
#      country              country_long                 name   gppd_idnr  \
# 9853     USA  United States of America  RE Bruceville 1 LLC  USA0057783
#
#       capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 9853          5.0   38.3475  -121.4128        Solar         NaN         NaN
#
#       ... year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 9853  ...                2019.0                12.92              11.564
#
#      generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 9853              11.895               12.08               11.16
#
#       generation_gwh_2018  generation_gwh_2019  \
# 9853               11.418               10.922
#
#                       generation_data_source  estimated_generation_gwh
# 9853  U.S. Energy Information Administration                       NaN
#
# [1 rows x 27 columns]

# %%
dfnew.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
dfnew.columns.tolist()
# Out:
# ['country',
#  'country_long',
#  'name',
#  'gppd_idnr',
#  'capacity_mw',
#  'latitude',
#  'longitude',
#  'primary_fuel',
#  'other_fuel1',
#  'other_fuel2',
#  'other_fuel3',
#  'commissioning_year',
#  'owner',
#  'source',
#  'url',
#  'geolocation_source',
#  'wepp_id',
#  'year_of_capacity_data',
#  'generation_gwh_2013',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018',
#  'generation_gwh_2019',
#  'generation_data_source',
#  'estimated_generation_gwh']

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13298 entries, 0 to 13297
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   13298 non-null  object
#  1   country_long              13298 non-null  object
#  2   name                      13298 non-null  object
#  3   gppd_idnr                 13298 non-null  object
#  4   capacity_mw               13292 non-null  float64
#  5   latitude                  13220 non-null  float64
#  6   longitude                 13220 non-null  float64
#  7   primary_fuel              11294 non-null  object
#  8   other_fuel1               1628 non-null   object
#  9   other_fuel2               270 non-null    object
#  10  other_fuel3               92 non-null     object
#  11  commissioning_year        10654 non-null  float64
#  12  owner                     12705 non-null  object
# ...

# %% [markdown]
# # The data contains 13298 entries, dtype are object and float. The memory usuage of the data is 2.7+ MB

# %%
 dfnew.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                  object
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019          object
# generation_data_source       object
# ...

# %%
dfnew.isnull().sum()
# Out:
# country                         0
# country_long                    0
# name                            0
# gppd_idnr                       0
# capacity_mw                     6
# latitude                       78
# longitude                      78
# primary_fuel                 2004
# other_fuel1                 11670
# other_fuel2                 13028
# other_fuel3                 13206
# commissioning_year           2644
# owner                         593
# source                          0
# url                             0
# geolocation_source             23
# wepp_id                     13298
# year_of_capacity_data         438
# generation_gwh_2013          6128
# generation_gwh_2014          5764
# generation_gwh_2015          5305
# generation_gwh_2016          4597
# generation_gwh_2017          4006
# generation_gwh_2018          3440
# generation_gwh_2019          3520
# generation_data_source       2463
# estimated_generation_gwh    13298
# dtype: int64

# %% [markdown]
# Most of the data has missing values but the data with 0 value has no missing values.

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
dfnew.shape
# Out:
# (13298, 27)

# %%
#Checking for the collective value count of different data in each columns

for i in dfnew.columns:
    print(dfnew[i].value_counts())
    print("\n")
# Out:
# country
# USA    11879
# IND      907
# AUS      512
# Name: count, dtype: int64
#
#
# country_long
# United States of America    11879
# India                         907
# Australia                     512
# Name: count, dtype: int64
#
#
# name
# Richland                      3
# Central Utility Plant         2
# Gladstone                     2
# Franklin Solar                2
# Hunter                        2
#                              ..
# E F Barrett                   1
# E F Oxnard Energy Facility    1
# E J West                      1
# E Nash PV1                    1
# eBay - South Jordan           1
# Name: count, Length: 13266, dtype: int64
#
#
# gppd_idnr
# AUS0000433    1
# USA0062255    1
# USA0006180    1
# USA0057489    1
# USA0061333    1
#              ..
# USA0006378    1
# USA0000840    1
# USA0050818    1
# USA0062324    1
# USA0059281    1
# Name: count, Length: 13298, dtype: int64
#
#
# capacity_mw
# 0.0      2030
# 5.0       552
# 1.0       534
# ...

# %%
dfnew.nunique().to_frame('DIFFERENT UNIQUE VALUE')
# Out:
#                           DIFFERENT UNIQUE VALUE
# country                                        3
# country_long                                   3
# name                                       13266
# gppd_idnr                                  13298
# capacity_mw                                 2304
# latitude                                   12385
# longitude                                  12733
# primary_fuel                                  14
# other_fuel1                                   12
# other_fuel2                                   11
# other_fuel3                                    9
# commissioning_year                          1936
# owner                                       5877
# source                                       206
# url                                          325
# geolocation_source                             5
# wepp_id                                        0
# year_of_capacity_data                          1
# ...

# %% [markdown]
# # FOR DATA VISUALIZATION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
sns.countplot(x='country',data=dfnew)

print(dfnew['country'].value_counts())
# Out:
# country
# USA    11879
# IND      907
# AUS      512
# Name: count, dtype: int64

# %% [markdown]
# The above data USA has the hight power plant, followed to IND and AUS shows the least.

# %%
sns.countplot(x='country_long',data=dfnew)

print(dfnew['country_long'].value_counts())
# Out:
# country_long
# United States of America    11879
# India                         907
# Australia                     512
# Name: count, dtype: int64

# %% [markdown]
# The country long shows that United State of America has the highest domination of the conutry_long

# %%
sns.countplot(x='primary_fuel',data=dfnew)

print(dfnew['primary_fuel'].value_counts())
# Out:
# primary_fuel
# Solar           3480
# Gas             2031
# Hydro           1783
# Wind            1340
# Oil              961
# Waste            595
# Coal             572
# Biomass          230
# Storage          104
# Nuclear           72
# Geothermal        65
# Cogeneration      34
# Other             16
# Petcoke           11
# Name: count, dtype: int64

# %% [markdown]
# The graph shows that the first highest primary fuel are the solar,gas and hydro whereas petcoke is the smallest primary fuel generated

# %%
sns.countplot(x='other_fuel1',data=dfnew)

print(dfnew['other_fuel1'].value_counts())
# Out:
# other_fuel1
# Oil             986
# Gas             351
# Coal             71
# Waste            63
# Storage          43
# Solar            30
# Hydro            20
# Biomass          19
# Other            17
# Petcoke          15
# Wind              7
# Cogeneration      6
# Name: count, dtype: int64

# %% [markdown]
# The above graph shows that oil is the greatest among the other fuel1 used, followed by coal but the least id cogeneration

# %%
sns.countplot(x='other_fuel2',data=dfnew)

print(dfnew['other_fuel2'].value_counts())
# Out:
# other_fuel2
# Gas        87
# Oil        62
# Other      32
# Waste      31
# Biomass    18
# Solar      17
# Storage     6
# Hydro       6
# Wind        4
# Petcoke     4
# Coal        3
# Name: count, dtype: int64

# %%
sns.countplot(x='other_fuel3',data=dfnew)

print(dfnew['other_fuel3'].value_counts())
# Out:
# other_fuel3
# Gas        34
# Other      20
# Biomass    13
# Hydro       6
# Solar       5
# Waste       5
# Oil         5
# Wind        2
# Storage     2
# Name: count, dtype: int64

# %%
sns.countplot(x='geolocation_source',data=dfnew)

print(dfnew['geolocation_source'].value_counts())
# Out:
# geolocation_source
# U.S. Energy Information Administration                11833
# WRI                                                     807
# Australian Renewable Energy Mapping Infrastructure      512
# Industry About                                          119
# National Renewable Energy Laboratory                      4
# Name: count, dtype: int64

# %% [markdown]
# From the geolocation_source in U.S. Energy Information Administration got the highest energy information while the industry about gives very minimal source

# %%
sns.countplot(x='generation_data_source',data=dfnew)

print(dfnew['generation_data_source'].value_counts())
# Out:
# generation_data_source
# U.S. Energy Information Administration    10069
# Central Electricity Authority               454
# Australia Clean Energy Regulator            312
# Name: count, dtype: int64

# %% [markdown]
# The U.S energy information administration generate the greatest data source.The data source from the from central electricity authority is slightly higher than the data gathered from the Australian clean energy regulation

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# ...

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13298 entries, 0 to 13297
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   13298 non-null  object
#  1   country_long              13298 non-null  object
#  2   name                      13298 non-null  object
#  3   gppd_idnr                 13298 non-null  object
#  4   capacity_mw               13292 non-null  float64
#  5   latitude                  13220 non-null  float64
#  6   longitude                 13220 non-null  float64
#  7   primary_fuel              11294 non-null  object
#  8   other_fuel1               1628 non-null   object
#  9   other_fuel2               270 non-null    object
#  10  other_fuel3               92 non-null     object
#  11  commissioning_year        10654 non-null  float64
#  12  owner                     12705 non-null  object
# ...

# %%
dfnew.isnull().sum()
# Out:
# country                         0
# country_long                    0
# name                            0
# gppd_idnr                       0
# capacity_mw                     6
# latitude                       78
# longitude                      78
# primary_fuel                 2004
# other_fuel1                 11670
# other_fuel2                 13028
# other_fuel3                 13206
# commissioning_year           2644
# owner                         593
# source                          0
# url                             0
# geolocation_source             23
# wepp_id                     13298
# year_of_capacity_data         438
# generation_gwh_2013          6128
# generation_gwh_2014          5764
# generation_gwh_2015          5305
# generation_gwh_2016          4597
# generation_gwh_2017          4006
# generation_gwh_2018          3440
# generation_gwh_2019          3520
# generation_data_source       2463
# estimated_generation_gwh    13298
# dtype: int64

# %%
dfnew.nunique()
# Out:
# country                         3
# country_long                    3
# name                        13266
# gppd_idnr                   13298
# capacity_mw                  2304
# latitude                    12385
# longitude                   12733
# primary_fuel                   14
# other_fuel1                    12
# other_fuel2                    11
# other_fuel3                     9
# commissioning_year           1936
# owner                        5877
# source                        206
# url                           325
# geolocation_source              5
# wepp_id                         0
# year_of_capacity_data           1
# generation_gwh_2013          5616
# generation_gwh_2014          6306
# generation_gwh_2015          6692
# generation_gwh_2016          7150
# generation_gwh_2017          7630
# generation_gwh_2018          8040
# generation_gwh_2019          8368
# generation_data_source          3
# estimated_generation_gwh        0
# dtype: int64

# %%
dfnew.isnull().sum()
# Out:
# country                         0
# country_long                    0
# name                            0
# gppd_idnr                       0
# capacity_mw                     6
# latitude                       78
# longitude                      78
# primary_fuel                 2004
# other_fuel1                 11670
# other_fuel2                 13028
# other_fuel3                 13206
# commissioning_year           2644
# owner                         593
# source                          0
# url                             0
# geolocation_source             23
# wepp_id                     13298
# year_of_capacity_data         438
# generation_gwh_2013          6128
# generation_gwh_2014          5764
# generation_gwh_2015          5305
# generation_gwh_2016          4597
# generation_gwh_2017          4006
# generation_gwh_2018          3440
# generation_gwh_2019          3520
# generation_data_source       2463
# estimated_generation_gwh    13298
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

# %%
dfnew['capacity_mw']=le.fit_transform(dfnew['capacity_mw'])

# %%
dfnew['latitude']=le.fit_transform(dfnew['latitude'])

# %%
dfnew['longitude']=le.fit_transform(dfnew['longitude'])

# %%
dfnew['primary_fuel']=le.fit_transform(dfnew['primary_fuel'])

# %%
dfnew['other_fuel1']=le.fit_transform(dfnew['other_fuel1'])

# %%
dfnew['other_fuel2']=le.fit_transform(dfnew['other_fuel2'])

# %%
dfnew['other_fuel3']=le.fit_transform(dfnew['other_fuel3'])

# %%
dfnew['commissioning_year']=le.fit_transform(dfnew['commissioning_year'])

# %%
dfnew['owner']=le.fit_transform(dfnew['owner'])

# %%
dfnew['geolocation_source']=le.fit_transform(dfnew['geolocation_source'])

# %%
dfnew['wepp_id']=le.fit_transform(dfnew['wepp_id'])

# %%
dfnew['year_of_capacity_data']=le.fit_transform(dfnew['year_of_capacity_data'])

# %%
dfnew['generation_gwh_2013']=le.fit_transform(dfnew['generation_gwh_2013'])

# %%
dfnew['generation_gwh_2014']=le.fit_transform(dfnew['generation_gwh_2014'])

# %%
dfnew['generation_gwh_2015']=le.fit_transform(dfnew['generation_gwh_2015'])

# %%
dfnew['generation_gwh_2016']=le.fit_transform(dfnew['generation_gwh_2016'])

# %%
dfnew['generation_gwh_2017']=le.fit_transform(dfnew['generation_gwh_2017'])

# %%
dfnew['generation_gwh_2018']=le.fit_transform(dfnew['generation_gwh_2018'])

# %%
dfnew['generation_data_source']=le.fit_transform(dfnew['generation_data_source'])

# %%
dfnew.isnull().sum()
# Out:
# country                         0
# country_long                    0
# name                            0
# gppd_idnr                       0
# capacity_mw                     0
# latitude                        0
# longitude                       0
# primary_fuel                    0
# other_fuel1                     0
# other_fuel2                     0
# other_fuel3                     0
# commissioning_year              0
# owner                           0
# source                          0
# url                             0
# geolocation_source              0
# wepp_id                         0
# year_of_capacity_data           0
# generation_gwh_2013             0
# generation_gwh_2014             0
# generation_gwh_2015             0
# generation_gwh_2016             0
# generation_gwh_2017             0
# generation_gwh_2018             0
# generation_gwh_2019          3520
# generation_data_source          0
# estimated_generation_gwh    13298
# dtype: int64

# %%
dfnew.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                   int64
# latitude                      int64
# longitude                     int64
# primary_fuel                  int32
# other_fuel1                   int32
# other_fuel2                   int32
# other_fuel3                   int32
# commissioning_year            int64
# owner                         int32
# source                       object
# url                          object
# geolocation_source            int32
# wepp_id                       int64
# year_of_capacity_data         int64
# generation_gwh_2013           int64
# generation_gwh_2014           int64
# generation_gwh_2015           int64
# generation_gwh_2016           int64
# generation_gwh_2017           int64
# generation_gwh_2018           int64
# generation_gwh_2019          object
# generation_data_source        int32
# ...

# %%
dfnew['estimated_generation_gwh'] =dfnew['estimated_generation_gwh'].astype(object)

# %%
dfnew.dtypes
# Out:
# country                     object
# country_long                object
# name                        object
# gppd_idnr                   object
# capacity_mw                  int64
# latitude                     int64
# longitude                    int64
# primary_fuel                 int32
# other_fuel1                  int32
# other_fuel2                  int32
# other_fuel3                  int32
# commissioning_year           int64
# owner                        int32
# source                      object
# url                         object
# geolocation_source           int32
# wepp_id                      int64
# year_of_capacity_data        int64
# generation_gwh_2013          int64
# generation_gwh_2014          int64
# generation_gwh_2015          int64
# generation_gwh_2016          int64
# generation_gwh_2017          int64
# generation_gwh_2018          int64
# generation_gwh_2019         object
# generation_data_source       int32
# estimated_generation_gwh    object
# ...

# %%
print('The mean value of generation_gwh_2019 is:', df['generation_gwh_2019'].mean())
# Out:
# The mean value of generation_gwh_2019 is: nan

# %%
df["generation_gwh_2019"]=df["generation_gwh_2019"].fillna(df["generation_gwh_2019"].mean())

# %%
print('The mean value of estimated_generation_gwh is:', df['estimated_generation_gwh'].mean())
# Out:
# The mean value of estimated_generation_gwh is: nan

# %% [markdown]
# The mean value of estimation_generation_gwh shows that there nan ia all the columns and for this reason the column need to be drop

# %%
dfnew.dtypes
# Out:
# country                     object
# country_long                object
# name                        object
# gppd_idnr                   object
# capacity_mw                  int64
# latitude                     int64
# longitude                    int64
# primary_fuel                 int32
# other_fuel1                  int32
# other_fuel2                  int32
# other_fuel3                  int32
# commissioning_year           int64
# owner                        int32
# source                      object
# url                         object
# geolocation_source           int32
# wepp_id                      int64
# year_of_capacity_data        int64
# generation_gwh_2013          int64
# generation_gwh_2014          int64
# generation_gwh_2015          int64
# generation_gwh_2016          int64
# generation_gwh_2017          int64
# generation_gwh_2018          int64
# generation_gwh_2019         object
# generation_data_source       int32
# estimated_generation_gwh    object
# ...

# %%
dfnew.isnull().sum()
# Out:
# country                         0
# country_long                    0
# name                            0
# gppd_idnr                       0
# capacity_mw                     0
# latitude                        0
# longitude                       0
# primary_fuel                    0
# other_fuel1                     0
# other_fuel2                     0
# other_fuel3                     0
# commissioning_year              0
# owner                           0
# source                          0
# url                             0
# geolocation_source              0
# wepp_id                         0
# year_of_capacity_data           0
# generation_gwh_2013             0
# generation_gwh_2014             0
# generation_gwh_2015             0
# generation_gwh_2016             0
# generation_gwh_2017             0
# generation_gwh_2018             0
# generation_gwh_2019          3520
# generation_data_source          0
# estimated_generation_gwh    13298
# dtype: int64

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# ...

# %%
dfnew.drop(['estimated_generation_gwh'],axis=1, inplace=True)

# %%
dfnew.drop(['generation_gwh_2019'],axis=1, inplace=True)

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# ...

# %%
dfnew.describe()
# Out:
#         capacity_mw      latitude     longitude  primary_fuel   other_fuel1  \
# count  13298.000000  13298.000000  13298.000000  13298.000000  13298.000000
# mean     394.214168   6253.874342   6390.527448      8.411340     11.108964
# std      570.936936   3564.019540   3699.238892      4.256073      2.475831
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       35.000000   3203.250000   3167.000000      5.000000     12.000000
# 50%       91.000000   6267.500000   6398.500000     10.000000     12.000000
# 75%      530.750000   9316.750000   9590.750000     13.000000     12.000000
# max     2304.000000  12385.000000  12733.000000     14.000000     12.000000
#
#         other_fuel2   other_fuel3  commissioning_year         owner  \
# count  13298.000000  13298.000000        13298.000000  13298.000000
# mean      10.860355      8.954956         1528.979922   3006.193713
# std        1.040421      0.568403          548.205854   1765.208580
# ...

# %%
dfnew.dtypes
# Out:
# country                   object
# country_long              object
# name                      object
# gppd_idnr                 object
# capacity_mw                int64
# latitude                   int64
# longitude                  int64
# primary_fuel               int32
# other_fuel1                int32
# other_fuel2                int32
# other_fuel3                int32
# commissioning_year         int64
# owner                      int32
# source                    object
# url                       object
# geolocation_source         int32
# wepp_id                    int64
# year_of_capacity_data      int64
# generation_gwh_2013        int64
# generation_gwh_2014        int64
# generation_gwh_2015        int64
# generation_gwh_2016        int64
# generation_gwh_2017        int64
# generation_gwh_2018        int64
# generation_data_source     int32
# dtype: object

# %%
sns.heatmap(dfnew.isnull(), cmap="cool_r")
# Out:
# <Axes: >

# %%
dfnew
# Out:
#       country              country_long                           name  \
# 0         AUS                 Australia               Adelaide Airport
# 1         AUS                 Australia           Adelaide Showgrounds
# 2         AUS                 Australia               Albany Wind Farm
# 3         AUS                 Australia          Alice Springs Airport
# 4         AUS                 Australia                   Amcor Gawler
# ...       ...                       ...                            ...
# 13293     USA  United States of America       Zotos International WPGF
# 13294     USA  United States of America  Zumbro Community Solar Garden
# 13295     USA  United States of America            Zumbro Solar Garden
# 13296     USA  United States of America                           Zuni
# 13297     USA  United States of America            eBay - South Jordan
#
#         gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# ...

# %%
dfnew.head(10)
# Out:
#   country country_long                   name   gppd_idnr  capacity_mw  \
# 0     AUS    Australia       Adelaide Airport  AUS0000433            4
# 1     AUS    Australia   Adelaide Showgrounds  AUS0000432           28
# 2     AUS    Australia       Albany Wind Farm  AUS0000065          268
# 3     AUS    Australia  Alice Springs Airport  AUS0000469           12
# 4     AUS    Australia           Amcor Gawler  AUS0000231           69
# 5     AUS    Australia               Angaston  AUS0000232          506
# 6     AUS    Australia               Anglesea  AUS0000114         1074
# 7     AUS    Australia               Angurugu  AUS0000615           62
# 8     AUS    Australia           Appin (Mine)  AUS0000264          549
# 9     AUS    Australia       Ararat Wind Farm  AUS0000611         1266
#
#    latitude  longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# 0       159      12390            10           12           11  ...
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in dfnew.columns:
    if dfnew[i].dtypes=='object':
        dfnew[i]=OE.fit_transform(dfnew[i].values.reshape(-1,1))
        
dfnew
# Out:
#        country  country_long     name  gppd_idnr  capacity_mw  latitude  \
# 0          0.0           0.0    192.0      411.0            4       159
# 1          0.0           0.0    193.0      410.0           28       158
# 2          0.0           0.0    254.0       60.0          268       154
# 3          0.0           0.0    280.0      446.0           12       398
# 4          0.0           0.0    380.0      223.0           69       181
# ...        ...           ...      ...        ...          ...       ...
# 13293      2.0           2.0  13260.0     7059.0           60      9943
# 13294      2.0           2.0  13261.0    10616.0           28     10953
# 13295      2.0           2.0  13262.0    12370.0            0     10720
# 13296      2.0           2.0  13263.0     1352.0            0      7026
# 13297      2.0           2.0  13264.0     8526.0          140      7705
#
#        longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# ...

# %%
#This was droped at it shows that all/most the data is empty

dfnew.drop(['wepp_id'],axis=1, inplace=True)

# %%
dfnew.corr()
# Out:
#                          country  country_long      name  gppd_idnr  \
# country                 1.000000      1.000000 -0.016444   0.310570
# country_long            1.000000      1.000000 -0.016444   0.310570
# name                   -0.016444     -0.016444  1.000000  -0.003858
# gppd_idnr               0.310570      0.310570 -0.003858   1.000000
# capacity_mw            -0.166862     -0.166862 -0.014870  -0.384891
# latitude                0.484818      0.484818 -0.006686   0.086962
# longitude              -0.506871     -0.506871 -0.003678  -0.049434
# primary_fuel            0.181917      0.181917  0.010583   0.483915
# other_fuel1            -0.022187     -0.022187  0.000348   0.271044
# other_fuel2            -0.042332     -0.042332  0.002209   0.090571
# other_fuel3            -0.025660     -0.025660 -0.007239   0.049235
# commissioning_year     -0.048845     -0.048845 -0.004174   0.620832
# owner                  -0.149254     -0.149254  0.291284  -0.077982
# ...

# %%
plt.figure(figsize = (20,15))

sns.heatmap(dfnew.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
dfnew
# Out:
#        country  country_long     name  gppd_idnr  capacity_mw  latitude  \
# 0          0.0           0.0    192.0      411.0            4       159
# 1          0.0           0.0    193.0      410.0           28       158
# 2          0.0           0.0    254.0       60.0          268       154
# 3          0.0           0.0    280.0      446.0           12       398
# 4          0.0           0.0    380.0      223.0           69       181
# ...        ...           ...      ...        ...          ...       ...
# 13293      2.0           2.0  13260.0     7059.0           60      9943
# 13294      2.0           2.0  13261.0    10616.0           28     10953
# 13295      2.0           2.0  13262.0    12370.0            0     10720
# 13296      2.0           2.0  13263.0     1352.0            0      7026
# 13297      2.0           2.0  13264.0     8526.0          140      7705
#
#        longitude  primary_fuel  other_fuel1  other_fuel2  ...    url  \
# ...

# %% [markdown]
# # To check for the presence of outliers

# %%
dfnew.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))
# Out:
# country                      Axes(0.125,0.712609;0.110714x0.167391)
# country_long              Axes(0.257857,0.712609;0.110714x0.167391)
# name                      Axes(0.390714,0.712609;0.110714x0.167391)
# gppd_idnr                 Axes(0.523571,0.712609;0.110714x0.167391)
# capacity_mw               Axes(0.656429,0.712609;0.110714x0.167391)
# latitude                  Axes(0.789286,0.712609;0.110714x0.167391)
# longitude                    Axes(0.125,0.511739;0.110714x0.167391)
# primary_fuel              Axes(0.257857,0.511739;0.110714x0.167391)
# other_fuel1               Axes(0.390714,0.511739;0.110714x0.167391)
# other_fuel2               Axes(0.523571,0.511739;0.110714x0.167391)
# other_fuel3               Axes(0.656429,0.511739;0.110714x0.167391)
# commissioning_year        Axes(0.789286,0.511739;0.110714x0.167391)
# owner                         Axes(0.125,0.31087;0.110714x0.167391)
# source                     Axes(0.257857,0.31087;0.110714x0.167391)
# ...

# %% [markdown]
# There is presence of outliers in country, country_long,capacity_mw,other fuel1,other fuel2,other fuel3,commissioning_year,source,url,geolocation source,year_of_capacity and generation_data_source

# %% [markdown]
# # REMOVING THE OUTLIERS USING ZSCORE

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
z=np.abs(zscore(dfnew))

z
# Out:
#         country  country_long      name  gppd_idnr  capacity_mw  latitude  \
# 0      4.135791      4.135791  1.681389   1.624856     0.683489  1.710177
# 1      4.135791      4.135791  1.681128   1.625116     0.641451  1.710457
# 2      4.135791      4.135791  1.665201   1.716291     0.221073  1.711580
# 3      4.135791      4.135791  1.658412   1.615738     0.669476  1.643115
# 4      4.135791      4.135791  1.632303   1.673830     0.569636  1.704004
# ...         ...           ...       ...        ...          ...       ...
# 13293  0.323787      0.323787  1.730607   0.106934     0.585400  1.035141
# 13294  0.323787      0.323787  1.730868   1.033526     0.641451  1.318540
# 13295  0.323787      0.323787  1.731129   1.490439     0.690495  1.253162
# 13296  0.323787      0.323787  1.731390   1.379727     0.690495  0.216653
# 13297  0.323787      0.323787  1.731651   0.489085     0.445275  0.407175
#
#        longitude  primary_fuel  other_fuel1  other_fuel2  ...       url  \
# ...

# %%
#assume the threshold to be 3

print(np.where(z>3))
# Out:
# (array([    0,     0,     0, ..., 13254, 13260, 13265], dtype=int64), array([ 0,  1, 13, ...,  8, 16,  4], dtype=int64))

# %%
dfnew=dfnew[(z<3).all(axis=1)]

dfnew
# Out:
#        country  country_long     name  gppd_idnr  capacity_mw  latitude  \
# 515        1.0           1.0    105.0      512.0          975      1175
# 517        1.0           1.0    110.0      514.0         1284      1168
# 518        1.0           1.0    114.0      515.0          581       558
# 519        1.0           1.0    115.0      516.0         1153      2291
# 520        1.0           1.0    116.0      517.0         1359       693
# ...        ...           ...      ...        ...          ...       ...
# 13293      2.0           2.0  13260.0     7059.0           60      9943
# 13294      2.0           2.0  13261.0    10616.0           28     10953
# 13295      2.0           2.0  13262.0    12370.0            0     10720
# 13296      2.0           2.0  13263.0     1352.0            0      7026
# 13297      2.0           2.0  13264.0     8526.0          140      7705
#
#        longitude  primary_fuel  other_fuel1  other_fuel2  ...   url  \
# ...

# %%
dfnew
# Out:
#        country  country_long     name  gppd_idnr  capacity_mw  latitude  \
# 515        1.0           1.0    105.0      512.0          975      1175
# 517        1.0           1.0    110.0      514.0         1284      1168
# 518        1.0           1.0    114.0      515.0          581       558
# 519        1.0           1.0    115.0      516.0         1153      2291
# 520        1.0           1.0    116.0      517.0         1359       693
# ...        ...           ...      ...        ...          ...       ...
# 13293      2.0           2.0  13260.0     7059.0           60      9943
# 13294      2.0           2.0  13261.0    10616.0           28     10953
# 13295      2.0           2.0  13262.0    12370.0            0     10720
# 13296      2.0           2.0  13263.0     1352.0            0      7026
# 13297      2.0           2.0  13264.0     8526.0          140      7705
#
#        longitude  primary_fuel  other_fuel1  other_fuel2  ...   url  \
# ...

# %%
x = dfnew.drop('capacity_mw', axis = 1)

y = dfnew['capacity_mw']

# %%
y.value_counts()
# Out:
# capacity_mw
# 0       2029
# 84       511
# 28       495
# 41       466
# 35       255
#         ...
# 888        1
# 617        1
# 2028       1
# 1125       1
# 1681       1
# Name: count, Length: 1862, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0

maxRS =0 

for i in range (1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximuim accuracy score:', maxAccu,'Random_State:', maxRS)
# Out:
# Maximuim accuracy score: 0.5537526835609303 Random_State: 84

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=maxRS)

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predlr=lr.predict(x_test)
pred_train=lr.predict(x_train)




print('accuracy score',r2_score(y_test,predlr))
# Out:
# accuracy score 0.5420071539594653

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)




print('accuracy score',r2_score(y_test,predRFR))
# Out:
# accuracy score 0.9060420321765058

# %%
knn=KNN()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
predknn=knn.predict(x_test)
pred_train=knn.predict(x_train)




print('accuracy score',r2_score(y_test,predknn))
# Out:
# accuracy score 0.5219900943671719

# %% [markdown]
# # Tthe model with best accuracy is better and it is Random Forest Regressor

# %% [markdown]
# # TO SAVE THE MODEL

# %%
import joblib

# %%
joblib.dump(RFR,'Next_Tmax.PKI')
# Out:
# ['Next_Tmax.PKI']

# %% [markdown]
# # FOR THE PREDICTION OF PRIMARY FUEL

# %%
dfnew
# Out:
#        country  country_long     name  gppd_idnr  capacity_mw  latitude  \
# 515        1.0           1.0    105.0      512.0          975      1175
# 517        1.0           1.0    110.0      514.0         1284      1168
# 518        1.0           1.0    114.0      515.0          581       558
# 519        1.0           1.0    115.0      516.0         1153      2291
# 520        1.0           1.0    116.0      517.0         1359       693
# ...        ...           ...      ...        ...          ...       ...
# 13293      2.0           2.0  13260.0     7059.0           60      9943
# 13294      2.0           2.0  13261.0    10616.0           28     10953
# 13295      2.0           2.0  13262.0    12370.0            0     10720
# 13296      2.0           2.0  13263.0     1352.0            0      7026
# 13297      2.0           2.0  13264.0     8526.0          140      7705
#
#        longitude  primary_fuel  other_fuel1  other_fuel2  ...   url  \
# ...

# %%
x = df.drop('primary_fuel', axis = 1)

y = df['primary_fuel']

# %%
y.value_counts()
# Out:
# primary_fuel
# Gas        140
# Wind        76
# Hydro       76
# Solar       62
# Oil         55
# Waste       50
# Coal        28
# Biomass     25
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=45)

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
