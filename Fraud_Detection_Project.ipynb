# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
fd=pd.read_csv('insurance.csv')

fd
# Out:
#      328  48  521585  17-10-2014  OH   250/500  1000  1406.91        0  \
# 0    228  42  342868  27-06-2006  IN   250/500  2000  1197.22  5000000
# 1    134  29  687698  06-09-2000  OH   100/300  2000  1413.14  5000000
# 2    256  41  227811  25-05-1990  IL   250/500  2000  1415.74  6000000
# 3    228  44  367455  06-06-2014  IL  500/1000  1000  1583.91  6000000
# 4    256  39  104594  12-10-2006  OH   250/500  1000  1351.10        0
# ..   ...  ..     ...         ...  ..       ...   ...      ...      ...
# 994    3  38  941851  16-07-1991  OH  500/1000  1000  1310.80        0
# 995  285  41  186934  05-01-2014  IL   100/300  1000  1436.79        0
# 996  130  34  918516  17-02-2003  OH   250/500   500  1383.49  3000000
# 997  458  62  533940  18-11-2011  IL  500/1000  2000  1356.92  5000000
# 998  456  60  556080  11-11-1996  OH   250/500  1000   766.19        0
#
#      466132  ...  2 YES.1   71610   6510  13020  52080        Saab      92x  \
# ...

# %%
fd.columns=['months_as_customer','age','policy_number','policy_bind_date','policy_state','policy_csl','policy_deductable','policy_annual_premium','umbrella_limit','insured_zip','insured_sex','insured_education_leve','insured_occupation','insured_hobbies','insured_relationship','capital_gain','capital_loss','incident_date','incident_type','collision_type','incident_severity','authority_contacted','incident_state','incident_city','incident_location','incident_hours_of_the_day','number_of_vehicles_involved','property_damage','bodily_injuries','witness','police_report_available','total_claim_amount','injury_claim','property_claim','vehicle_claim','auto_make','auto_model','auto_year','fraud_reported']

# %%
fd
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   228   42         342868       27-06-2006           IN
# 1                   134   29         687698       06-09-2000           OH
# 2                   256   41         227811       25-05-1990           IL
# 3                   228   44         367455       06-06-2014           IL
# 4                   256   39         104594       12-10-2006           OH
# ..                  ...  ...            ...              ...          ...
# 994                   3   38         941851       16-07-1991           OH
# 995                 285   41         186934       05-01-2014           IL
# 996                 130   34         918516       17-02-2003           OH
# 997                 458   62         533940       18-11-2011           IL
# 998                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
fd.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 228   42         342868       27-06-2006           IN
# 1                 134   29         687698       06-09-2000           OH
# 2                 256   41         227811       25-05-1990           IL
# 3                 228   44         367455       06-06-2014           IL
# 4                 256   39         104594       12-10-2006           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               2000                1197.22         5000000
# 1    100/300               2000                1413.14         5000000
# 2    250/500               2000                1415.74         6000000
# 3   500/1000               1000                1583.91         6000000
# 4    250/500               1000                1351.10               0
#
#    insured_zip  ... witness police_report_available total_claim_amount  \
# ...

# %%
fd.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 994                   3   38         941851       16-07-1991           OH
# 995                 285   41         186934       05-01-2014           IL
# 996                 130   34         918516       17-02-2003           OH
# 997                 458   62         533940       18-11-2011           IL
# 998                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 994   500/1000               1000                1310.80               0
# 995    100/300               1000                1436.79               0
# 996    250/500                500                1383.49         3000000
# 997   500/1000               2000                1356.92         5000000
# 998    250/500               1000                 766.19               0
#
#      insured_zip  ... witness police_report_available total_claim_amount  \
# ...

# %%
fd.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_leve          object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital_gain                     int64
# capital_loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authority_contacted             object
# incident_state                  object
# incident_city                   object
# ...

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_number                999 non-null    int64
#  3   policy_bind_date             999 non-null    object
#  4   policy_state                 999 non-null    object
#  5   policy_csl                   999 non-null    object
#  6   policy_deductable            999 non-null    int64
#  7   policy_annual_premium        999 non-null    float64
#  8   umbrella_limit               999 non-null    int64
#  9   insured_zip                  999 non-null    int64
#  10  insured_sex                  999 non-null    object
#  11  insured_education_leve       999 non-null    object
#  12  insured_occupation           999 non-null    object
# ...

# %%
fd.isnull().sum()
# Out:
# months_as_customer              0
# age                             0
# policy_number                   0
# policy_bind_date                0
# policy_state                    0
# policy_csl                      0
# policy_deductable               0
# policy_annual_premium           0
# umbrella_limit                  0
# insured_zip                     0
# insured_sex                     0
# insured_education_leve          0
# insured_occupation              0
# insured_hobbies                 0
# insured_relationship            0
# capital_gain                    0
# capital_loss                    0
# incident_date                   0
# incident_type                   0
# collision_type                  0
# incident_severity               0
# authority_contacted            91
# incident_state                  0
# incident_city                   0
# incident_location               0
# incident_hours_of_the_day       0
# number_of_vehicles_involved     0
# ...

# %%
fd.columns.to_list()
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_bind_date',
#  'policy_state',
#  'policy_csl',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'insured_sex',
#  'insured_education_leve',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'capital_gain',
#  'capital_loss',
#  'incident_date',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authority_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_location',
#  'incident_hours_of_the_day',
#  'number_of_vehicles_involved',
#  'property_damage',
#  'bodily_injuries',
#  'witness',
#  'police_report_available',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_make',
#  'auto_model',
#  'auto_year',
#  'fraud_reported']

# %%
fd.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 228   42         342868       27-06-2006           IN
# 1                 134   29         687698       06-09-2000           OH
# 2                 256   41         227811       25-05-1990           IL
# 3                 228   44         367455       06-06-2014           IL
# 4                 256   39         104594       12-10-2006           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               2000                1197.22         5000000
# 1    100/300               2000                1413.14         5000000
# 2    250/500               2000                1415.74         6000000
# 3   500/1000               1000                1583.91         6000000
# 4    250/500               1000                1351.10               0
#
#    insured_zip  ... witness police_report_available total_claim_amount  \
# ...

# %%
for i in fd.columns:
    print(fd[i].value_counts())
    print("\n")
# Out:
# months_as_customer
# 194    8
# 230    7
# 140    7
# 101    7
# 128    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: count, Length: 391, dtype: int64
#
#
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 30    42
# 38    42
# 31    42
# 37    41
# 33    39
# 32    38
# 40    38
# 29    35
# 46    33
# 35    32
# 42    32
# 36    32
# 44    32
# 28    30
# 45    26
# 26    26
# 47    24
# 48    24
# 27    24
# 57    16
# 49    14
# 25    14
# 55    14
# 50    13
# 53    13
# 54    10
# 24    10
# 61    10
# 60     9
# 51     9
# 56     8
# 58     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
#
#
# policy_number
# 342868    1
# 757644    1
# 223404    1
# 991480    1
# 804219    1
#          ..
# 620855    1
# 583169    1
# 337677    1
# 445973    1
# 556080    1
# Name: count, Length: 999, dtype: int64
#
#
# policy_bind_date
# 05-08-1992    3
# ...

# %%
fd['collision_type']=fd['collision_type'].replace('?','Rear Collision')

fd['property_damage']=fd['property_damage'].replace('?','NO')

fd['police_report_available']=fd['police_report_available'].replace('?','NO')

# %%
fd['authority_contacted'].value_counts()
# Out:
# authority_contacted
# Police       291
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64

# %%
#To check for categorical columns

categorical_colum=[]
for i in fd.dtypes.index:
    if fd.dtypes[i]=="object":
        categorical_colum.append(i)
print("Categorical columns:",categorical_colum)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in fd.dtypes.index:
    if fd.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_leve', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authority_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']
#
#
# Numerical columns: ['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'capital_gain', 'capital_loss', 'incident_hours_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witness', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']

# %%
fd.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 228   42         342868       27-06-2006           IN
# 1                 134   29         687698       06-09-2000           OH
# 2                 256   41         227811       25-05-1990           IL
# 3                 228   44         367455       06-06-2014           IL
# 4                 256   39         104594       12-10-2006           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               2000                1197.22         5000000
# 1    100/300               2000                1413.14         5000000
# 2    250/500               2000                1415.74         6000000
# 3   500/1000               1000                1583.91         6000000
# 4    250/500               1000                1351.10               0
#
#    insured_zip  ... witness police_report_available total_claim_amount  \
# ...

# %%
print('min.PolicyDate=',fd.policy_bind_date.min())

print('max.PolicyDate=',fd.policy_bind_date.max())
# Out:
# min.PolicyDate= 01-01-2006
# max.PolicyDate= 31-12-2012

# %%
#Converting the datatype of date from object to datetime.

fd['policy_bind_date']=pd.to_datetime(fd['policy_bind_date'],format='%d-%M-%Y')

fd['policy_bind_date']
# Out:
# 0     2006-01-27 00:06:00
# 1     2000-01-06 00:09:00
# 2     1990-01-25 00:05:00
# 3     2014-01-06 00:06:00
# 4     2006-01-12 00:10:00
#               ...
# 994   1991-01-16 00:07:00
# 995   2014-01-05 00:01:00
# 996   2003-01-17 00:02:00
# 997   2011-01-18 00:11:00
# 998   1996-01-11 00:11:00
# Name: policy_bind_date, Length: 999, dtype: datetime64[ns]

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_number                999 non-null    int64
#  3   policy_bind_date             999 non-null    datetime64[ns]
#  4   policy_state                 999 non-null    object
#  5   policy_csl                   999 non-null    object
#  6   policy_deductable            999 non-null    int64
#  7   policy_annual_premium        999 non-null    float64
#  8   umbrella_limit               999 non-null    int64
#  9   insured_zip                  999 non-null    int64
#  10  insured_sex                  999 non-null    object
#  11  insured_education_leve       999 non-null    object
#  12  insured_occupation           999 non-null    object
# ...

# %%
print('min.INCIDENCEDate=',fd.incident_date.min())

print('max.INCIDENCEDate=',fd.incident_date.max())
# Out:
# min.INCIDENCEDate= 01-01-2015
# max.INCIDENCEDate= 31-01-2015

# %%
#Converting the datatype of date from object to datetime.

fd['incident_date']=pd.to_datetime(fd['incident_date'],format='%d-%M-%Y')

fd['incident_date']
# Out:
# 0     2015-01-21 00:01:00
# 1     2015-01-22 00:02:00
# 2     2015-01-10 00:01:00
# 3     2015-01-17 00:02:00
# 4     2015-01-02 00:01:00
#               ...
# 994   2015-01-22 00:02:00
# 995   2015-01-24 00:01:00
# 996   2015-01-23 00:01:00
# 997   2015-01-26 00:02:00
# 998   2015-01-26 00:02:00
# Name: incident_date, Length: 999, dtype: datetime64[ns]

# %%
#To check for categorical columns

categorical_colum=[]
for i in fd.dtypes.index:
    if fd.dtypes[i]=="object":
        categorical_colum.append(i)
print("Categorical columns:",categorical_colum)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in fd.dtypes.index:
    if fd.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_leve', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authority_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']
#
#
# Numerical columns: ['months_as_customer', 'age', 'policy_number', 'policy_bind_date', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'capital_gain', 'capital_loss', 'incident_date', 'incident_hours_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witness', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']

# %%
fd.head()
# Out:
#    months_as_customer  age  policy_number    policy_bind_date policy_state  \
# 0                 228   42         342868 2006-01-27 00:06:00           IN
# 1                 134   29         687698 2000-01-06 00:09:00           OH
# 2                 256   41         227811 1990-01-25 00:05:00           IL
# 3                 228   44         367455 2014-01-06 00:06:00           IL
# 4                 256   39         104594 2006-01-12 00:10:00           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               2000                1197.22         5000000
# 1    100/300               2000                1413.14         5000000
# 2    250/500               2000                1415.74         6000000
# 3   500/1000               1000                1583.91         6000000
# 4    250/500               1000                1351.10               0
#
#    insured_zip  ... witness police_report_available total_claim_amount  \
# ...

# %%
fd['collision_type'].value_counts()

#The value count has been changed as ? value was replaced by the highest in occurrenceie mode
# Out:
# collision_type
# Rear Collision     470
# Side Collision     275
# Front Collision    254
# Name: count, dtype: int64

# %%
fd['property_damage'].value_counts()

#The value count has been changed as ? value was replaced by the highest in occurrenceie mode
# Out:
# property_damage
# NO     698
# YES    301
# Name: count, dtype: int64

# %%
fd['police_report_available'].value_counts()

#The value count has been changed as ? value was replaced by the highest in occurrenceie mode
# Out:
# police_report_available
# NO     686
# YES    313
# Name: count, dtype: int64

# %% [markdown]
# # THE POSSIBLE DATA VISUALIZATION

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=fd.iloc[:,:-1])
plt.ylabel('injury_claim')
plt.title('The injured level in the fraud report')
# Out:
# Text(0.5, 1.0, 'The injured level in the fraud report')

# %%
sns.countplot(x='policy_state',palette='coolwarm',data=fd,hue='property_damage')
# Out:
# <Axes: xlabel='policy_state', ylabel='count'>

# %%
ma= sns.countplot(x='police_report_available',data=fd)

print(fd['police_report_available'].value_counts())
# Out:
# police_report_available
# NO     686
# YES    313
# Name: count, dtype: int64

# %%
sns.countplot(x='collision_type',palette='coolwarm',data=fd,hue='property_damage')

#THE PROPERTY THAT DID NOT DAMAGE DURING THE COLLISION TYPE ARE GREATER THAT THE DAMAGE ONES IN ALL THE COLLITION TYPE.
# Out:
# <Axes: xlabel='collision_type', ylabel='count'>

# %%
sns.countplot(x='police_report_available',palette='coolwarm',data=fd,hue='property_damage')


#THE POLICE_REPORT_AVAILABLE DURING PROPERTY DAMANGE IS LOW WHEN COMPARED TO THE REPORT WHICH WAS NOT AVAILABLE
# Out:
# <Axes: xlabel='police_report_available', ylabel='count'>

# %%
sns.countplot(x='policy_csl',palette='coolwarm',data=fd,hue='property_damage')


#THE POLICY_CSL IS MORE IN 100/300
# Out:
# <Axes: xlabel='policy_csl', ylabel='count'>

# %%
sns.countplot(x='policy_csl',palette='coolwarm',data=fd,hue='fraud_reported')


#THE POLICY_CSL HAD MORE OF NO FRAUD REPOT.
# Out:
# <Axes: xlabel='policy_csl', ylabel='count'>

# %%
sns.countplot(x='police_report_available',palette='coolwarm',data=fd,hue='fraud_reported')

#POLICY AVAILABLE REPORT SHOW THAT THE LEVEL OF REPORT IN THE AVAILABLE REPORT IS LOW WHEN COMPARED TO THE 'NO'
# Out:
# <Axes: xlabel='police_report_available', ylabel='count'>

# %%
ma= sns.countplot(x='policy_deductable',data=fd)

print(fd['policy_deductable'].value_counts())

#THE POLICY DEDUCTION IN 1000 IS MORE WITH THE LOWEST IN 200.
# Out:
# policy_deductable
# 1000    350
# 500     342
# 2000    307
# Name: count, dtype: int64

# %%
sns.countplot(y='umbrella_limit',palette='coolwarm',data=fd,hue='fraud_reported')
# Out:
# <Axes: xlabel='count', ylabel='umbrella_limit'>

# %%
sns.countplot(x='insured_sex',palette='coolwarm',data=fd,hue='fraud_reported')
# Out:
# <Axes: xlabel='insured_sex', ylabel='count'>

# %%
sns.countplot(y='insured_education_leve',palette='magma',data=fd,hue='fraud_reported')
# Out:
# <Axes: xlabel='count', ylabel='insured_education_leve'>

# %%
sns.countplot(y='insured_occupation',palette='magma',data=fd,hue='fraud_reported')
# Out:
# <Axes: xlabel='count', ylabel='insured_occupation'>

# %%
sns.countplot(x='insured_relationship',palette='seismic',data=fd,hue='fraud_reported')
# Out:
# <Axes: xlabel='insured_relationship', ylabel='count'>

# %%
sns.countplot(x='incident_type',palette='seismic',data=fd,hue='fraud_reported')
# Out:
# <Axes: xlabel='incident_type', ylabel='count'>

# %%
ma= sns.countplot(x='incident_type',data=fd)

print(fd['police_report_available'].value_counts())
# Out:
# police_report_available
# NO     686
# YES    313
# Name: count, dtype: int64

# %%
sns.countplot(x='incident_type',palette='seismic',data=fd,hue='incident_severity')
# Out:
# <Axes: xlabel='incident_type', ylabel='count'>

# %%
sns.countplot(x='authority_contacted',palette='seismic',data=fd,hue='incident_severity')
# Out:
# <Axes: xlabel='authority_contacted', ylabel='count'>

# %%
sns.countplot(x='incident_state',palette='seismic',data=fd,hue='incident_severity')
# Out:
# <Axes: xlabel='incident_state', ylabel='count'>

# %%
sns.countplot(x='incident_state',palette='seismic',data=fd,hue='number_of_vehicles_involved')
# Out:
# <Axes: xlabel='incident_state', ylabel='count'>

# %%
ma= sns.countplot(x='number_of_vehicles_involved',data=fd)

print(fd['number_of_vehicles_involved'].value_counts())
# Out:
# number_of_vehicles_involved
# 1    580
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64

# %%
sns.countplot(x='bodily_injuries',palette='seismic',data=fd,hue='witness')
# Out:
# <Axes: xlabel='bodily_injuries', ylabel='count'>

# %%
sns.countplot(x='fraud_reported',palette='seismic',data=fd,hue='police_report_available')
# Out:
# <Axes: xlabel='fraud_reported', ylabel='count'>

# %%
plt.figure(figsize = (10,6), facecolor='white')

plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        ax=plt.subplot(2, 2, plotnumber)
        sns.distplot(fd[col],color = 'm')
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %%
fd.plot(kind='box', subplots=True, layout=(4,6),figsize=(10,10))
# Out:
# months_as_customer                Axes(0.125,0.712609;0.110714x0.167391)
# age                            Axes(0.257857,0.712609;0.110714x0.167391)
# policy_number                  Axes(0.390714,0.712609;0.110714x0.167391)
# policy_deductable              Axes(0.523571,0.712609;0.110714x0.167391)
# policy_annual_premium          Axes(0.656429,0.712609;0.110714x0.167391)
# umbrella_limit                 Axes(0.789286,0.712609;0.110714x0.167391)
# insured_zip                       Axes(0.125,0.511739;0.110714x0.167391)
# capital_gain                   Axes(0.257857,0.511739;0.110714x0.167391)
# capital_loss                   Axes(0.390714,0.511739;0.110714x0.167391)
# incident_hours_of_the_day      Axes(0.523571,0.511739;0.110714x0.167391)
# number_of_vehicles_involved    Axes(0.656429,0.511739;0.110714x0.167391)
# bodily_injuries                Axes(0.789286,0.511739;0.110714x0.167391)
# witness                            Axes(0.125,0.31087;0.110714x0.167391)
# ...

# %%
fd.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_number                           int64
# policy_bind_date               datetime64[ns]
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_zip                             int64
# insured_sex                            object
# insured_education_leve                 object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital_gain                            int64
# capital_loss                            int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# ...

# %%
fd
# Out:
#      months_as_customer  age  policy_number    policy_bind_date policy_state  \
# 0                   228   42         342868 2006-01-27 00:06:00           IN
# 1                   134   29         687698 2000-01-06 00:09:00           OH
# 2                   256   41         227811 1990-01-25 00:05:00           IL
# 3                   228   44         367455 2014-01-06 00:06:00           IL
# 4                   256   39         104594 2006-01-12 00:10:00           OH
# ..                  ...  ...            ...                 ...          ...
# 994                   3   38         941851 1991-01-16 00:07:00           OH
# 995                 285   41         186934 2014-01-05 00:01:00           IL
# 996                 130   34         918516 2003-01-17 00:02:00           OH
# 997                 458   62         533940 2011-01-18 00:11:00           IL
# 998                 456   60         556080 1996-01-11 00:11:00           OH
#
# ...

# %%
fd.set_index('incident_date',inplace=True)

# %%
fd
# Out:
#                      months_as_customer  age  policy_number  \
# incident_date
# 2015-01-21 00:01:00                 228   42         342868
# 2015-01-22 00:02:00                 134   29         687698
# 2015-01-10 00:01:00                 256   41         227811
# 2015-01-17 00:02:00                 228   44         367455
# 2015-01-02 00:01:00                 256   39         104594
# ...                                 ...  ...            ...
# 2015-01-22 00:02:00                   3   38         941851
# 2015-01-24 00:01:00                 285   41         186934
# 2015-01-23 00:01:00                 130   34         918516
# 2015-01-26 00:02:00                 458   62         533940
# 2015-01-26 00:02:00                 456   60         556080
#
#                        policy_bind_date policy_state policy_csl  \
# incident_date
# 2015-01-21 00:01:00 2006-01-27 00:06:00           IN    250/500
# 2015-01-22 00:02:00 2000-01-06 00:09:00           OH    100/300
# ...

# %%
fd.nunique().to_frame("Number of unique values of this data")
# Out:
#                              Number of unique values of this data
# months_as_customer                                            391
# age                                                            46
# policy_number                                                 999
# policy_bind_date                                              950
# policy_state                                                    3
# policy_csl                                                      3
# policy_deductable                                               3
# policy_annual_premium                                         990
# umbrella_limit                                                 11
# insured_zip                                                   994
# insured_sex                                                     2
# insured_education_leve                                          7
# insured_occupation                                             14
# ...

# %%
fd
# Out:
#                      months_as_customer  age  policy_number  \
# incident_date
# 2015-01-21 00:01:00                 228   42         342868
# 2015-01-22 00:02:00                 134   29         687698
# 2015-01-10 00:01:00                 256   41         227811
# 2015-01-17 00:02:00                 228   44         367455
# 2015-01-02 00:01:00                 256   39         104594
# ...                                 ...  ...            ...
# 2015-01-22 00:02:00                   3   38         941851
# 2015-01-24 00:01:00                 285   41         186934
# 2015-01-23 00:01:00                 130   34         918516
# 2015-01-26 00:02:00                 458   62         533940
# 2015-01-26 00:02:00                 456   60         556080
#
#                        policy_bind_date policy_state policy_csl  \
# incident_date
# 2015-01-21 00:01:00 2006-01-27 00:06:00           IN    250/500
# 2015-01-22 00:02:00 2000-01-06 00:09:00           OH    100/300
# ...

# %%
#The policy binding date has to be drop

fd.drop(['policy_bind_date'],axis=1,inplace=True)

# %%
fd.drop(['policy_number'],axis=1,inplace=True)

#THE POLICY ID HAS TO BE REMOVED

# %%
fd
# Out:
#                      months_as_customer  age policy_state policy_csl  \
# incident_date
# 2015-01-21 00:01:00                 228   42           IN    250/500
# 2015-01-22 00:02:00                 134   29           OH    100/300
# 2015-01-10 00:01:00                 256   41           IL    250/500
# 2015-01-17 00:02:00                 228   44           IL   500/1000
# 2015-01-02 00:01:00                 256   39           OH    250/500
# ...                                 ...  ...          ...        ...
# 2015-01-22 00:02:00                   3   38           OH   500/1000
# 2015-01-24 00:01:00                 285   41           IL    100/300
# 2015-01-23 00:01:00                 130   34           OH    250/500
# 2015-01-26 00:02:00                 458   62           IL   500/1000
# 2015-01-26 00:02:00                 456   60           OH    250/500
#
#                      policy_deductable  policy_annual_premium  umbrella_limit  \
# incident_date
# ...

# %%
#To check for categorical columns

categorical_colum=[]
for i in fd.dtypes.index:
    if fd.dtypes[i]=="object":
        categorical_colum.append(i)
print("Categorical columns:",categorical_colum)
print("\n")

#checking for Numerical columns

numerical_col = []
for i in fd.dtypes.index:
    if fd.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Categorical columns: ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_leve', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authority_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']
#
#
# Numerical columns: ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'capital_gain', 'capital_loss', 'incident_hours_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witness', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']

# %%
categor=  ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_leve', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authority_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

le=LabelEncoder()

# %%
catego = ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_leve', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authority_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']

for mu in catego:
    fd[mu]=le.fit_transform(fd[mu].astype(str))

# %%
fd.head()
# Out:
#                      months_as_customer  age  policy_state  policy_csl  \
# incident_date
# 2015-01-21 00:01:00                 228   42             1           1
# 2015-01-22 00:02:00                 134   29             2           0
# 2015-01-10 00:01:00                 256   41             0           1
# 2015-01-17 00:02:00                 228   44             0           2
# 2015-01-02 00:01:00                 256   39             2           1
#
#                      policy_deductable  policy_annual_premium  umbrella_limit  \
# incident_date
# 2015-01-21 00:01:00               2000                1197.22         5000000
# 2015-01-22 00:02:00               2000                1413.14         5000000
# 2015-01-10 00:01:00               2000                1415.74         6000000
# 2015-01-17 00:02:00               1000                1583.91         6000000
# 2015-01-02 00:01:00               1000                1351.10               0
#
# ...

# %%
fd.isnull().sum()

#THERE IS NO MISSING VALUES
# Out:
# months_as_customer             0
# age                            0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_leve         0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital_gain                   0
# capital_loss                   0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authority_contacted            0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hours_of_the_day      0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witness                        0
# police_report_available        0
# ...

# %%
fd.dtypes

#DATATYPE IS INTTEGER AND FLOAT
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                     int32
# policy_csl                       int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_education_leve           int32
# insured_occupation               int32
# insured_hobbies                  int32
# insured_relationship             int32
# capital_gain                     int64
# capital_loss                     int64
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authority_contacted              int32
# incident_state                   int32
# incident_city                    int32
# incident_location                int32
# incident_hours_of_the_day        int64
# number_of_vehicles_involved      int64
# ...

# %%
fd.skew()

#THE UMBRELLA_LIMIT AND FRAUD REPORTED ARE SHOWS THERE IS MORE OUTLIERS
# Out:
# months_as_customer             0.364615
# age                            0.481461
# policy_state                  -0.024326
# policy_csl                     0.089067
# policy_deductable              0.477027
# policy_annual_premium          0.006022
# umbrella_limit                 1.805104
# insured_zip                    0.815086
# insured_sex                    0.150802
# insured_education_leve         0.001298
# insured_occupation            -0.060896
# insured_hobbies               -0.059941
# insured_relationship           0.076349
# capital_gain                   0.481352
# capital_loss                  -0.389813
# incident_type                  0.103399
# collision_type                -0.032150
# incident_severity              0.277762
# authority_contacted           -0.032840
# incident_state                -0.147805
# incident_city                  0.047574
# incident_location              0.000000
# incident_hours_of_the_day     -0.037615
# ...

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 999 entries, 2015-01-21 00:01:00 to 2015-01-26 00:02:00
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_state                 999 non-null    int32
#  3   policy_csl                   999 non-null    int32
#  4   policy_deductable            999 non-null    int64
#  5   policy_annual_premium        999 non-null    float64
#  6   umbrella_limit               999 non-null    int64
#  7   insured_zip                  999 non-null    int64
#  8   insured_sex                  999 non-null    int32
#  9   insured_education_leve       999 non-null    int32
#  10  insured_occupation           999 non-null    int32
#  11  insured_hobbies              999 non-null    int32
# ...

# %%
fd.describe()
# Out:
#        months_as_customer         age  policy_state  policy_csl  \
# count          999.000000  999.000000    999.000000  999.000000
# mean           203.829830   38.938939      1.013013    0.950951
# std            115.103809    9.140370      0.830790    0.804918
# min              0.000000   19.000000      0.000000    0.000000
# 25%            115.500000   32.000000      0.000000    0.000000
# 50%            199.000000   38.000000      1.000000    1.000000
# 75%            276.000000   44.000000      2.000000    2.000000
# max            479.000000   64.000000      2.000000    2.000000
#
#        policy_deductable  policy_annual_premium  umbrella_limit  \
# count         999.000000             999.000000    9.990000e+02
# mean         1136.136136            1256.255495    1.102102e+06
# std           612.155989             244.243187    2.298293e+06
# min           500.000000             433.330000   -1.000000e+06
# 25%           500.000000            1089.185000    0.000000e+00
# ...

# %%
fd.corr()
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922018     -0.001611
# age                                    0.922018  1.000000     -0.015729
# policy_state                          -0.001611 -0.015729      1.000000
# policy_csl                            -0.026901 -0.015253      0.000955
# policy_deductable                      0.027064  0.029423      0.010305
# policy_annual_premium                  0.004355  0.013801      0.011733
# umbrella_limit                         0.016027  0.018613     -0.029034
# insured_zip                            0.018436  0.026106      0.009366
# insured_sex                            0.059833  0.072347     -0.021789
# insured_education_leve                -0.001407  0.000442     -0.034988
# insured_occupation                     0.011078  0.018390     -0.029879
# insured_hobbies                       -0.095178 -0.082695     -0.040274
# ...

# %%
plt.figure(figsize = (20,15))

sns.heatmap(fd.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')

plt.yticks(rotation = 0);
plt.show()

# %%
plt.figure(figsize=(22, 7))

fd.corr()['fraud_reported'].sort_values(ascending = False).drop(['fraud_reported']).plot(kind='bar',color='m')

plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title('Correlation between the label FOR FRAUD DETECTION and feature using barplot', fontsize = 20)

plt.show()

#MAJORITY OF THE DATA ARE NOT HIGHLY CORRELATED

# %% [markdown]
# # TO CUT OFF THE OUTLIERS

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
z=np.abs(zscore(fd))

z

#REMOVING THE OUTLIERS USING ZSCORE.
# Out:
#                      months_as_customer       age  policy_state  policy_csl  \
# incident_date
# 2015-01-21 00:01:00            0.210091  0.335062      0.015671    0.060967
# 2015-01-22 00:02:00            0.606972  1.087912      1.188606    1.182018
# 2015-01-10 00:01:00            0.453472  0.225603      1.219948    0.060967
# 2015-01-17 00:02:00            0.210091  0.553982      1.219948    1.303953
# 2015-01-02 00:01:00            0.453472  0.006684      1.188606    0.060967
# ...                                 ...       ...           ...         ...
# 2015-01-22 00:02:00            1.745645  0.102776      1.188606    1.303953
# 2015-01-24 00:01:00            0.705544  0.225603      1.219948    1.182018
# 2015-01-23 00:01:00            0.641741  0.540614      1.188606    0.060967
# 2015-01-26 00:02:00            2.209288  2.524254      1.219948    1.303953
# 2015-01-26 00:02:00            2.191904  2.305334      1.188606    0.060967
#
# ...

# %%
#Taking the threshold to be 3

print(np.where(z>3))
# Out:
# (array([ 30,  47,  87, 114, 118, 228, 247, 261, 313, 429, 457, 499, 502,
#        656, 699, 762, 806, 874, 921, 974], dtype=int64), array([ 6,  6,  6,  6,  6,  5,  5,  6,  6,  6,  6, 30,  6,  6,  6,  5, 14,
#         6,  6,  6], dtype=int64))

# %%
fd=fd[(z<3).all(axis=1)]

fd
# Out:
#                      months_as_customer  age  policy_state  policy_csl  \
# incident_date
# 2015-01-21 00:01:00                 228   42             1           1
# 2015-01-22 00:02:00                 134   29             2           0
# 2015-01-10 00:01:00                 256   41             0           1
# 2015-01-17 00:02:00                 228   44             0           2
# 2015-01-02 00:01:00                 256   39             2           1
# ...                                 ...  ...           ...         ...
# 2015-01-22 00:02:00                   3   38             2           2
# 2015-01-24 00:01:00                 285   41             0           0
# 2015-01-23 00:01:00                 130   34             2           1
# 2015-01-26 00:02:00                 458   62             0           2
# 2015-01-26 00:02:00                 456   60             2           1
#
#                      policy_deductable  policy_annual_premium  umbrella_limit  \
# incident_date
# ...

# %%
x = fd.drop('fraud_reported', axis = 1)

y = fd['fraud_reported']

#LABELLING THE DEPENDENT AND INDEPENDENT VARIABLES

# %%
y.value_counts()

#the value value are not balanced
# Out:
# fraud_reported
# 0    740
# 1    239
# Name: count, dtype: int64

# %%
#Oversampling the data



from imblearn.over_sampling import SMOTE

SM = SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
#To check the value count of target column

y.value_counts()
# Out:
# fraud_reported
# 0    740
# 1    239
# Name: count, dtype: int64

# %%
y1.value_counts()
# Out:
# fraud_reported
# 1    740
# 0    740
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
maxAccu = 0
maxRS = 0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size = 0.30, random_state =i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best accuracy is ', maxAccu, 'at random_state', maxRS)
# Out:
# Best accuracy is  0.918918918918919 at random_state 113

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, roc_curve

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predGB=GB.predict(x_test)

# %%
print(accuracy_score(y_test,predGB))

print(confusion_matrix(y_test,predGB))

print(classification_report(y_test,predGB))
# Out:
# 0.8716216216216216
# [[195  29]
#  [ 28 192]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       224
#            1       0.87      0.87      0.87       220
#
#     accuracy                           0.87       444
#    macro avg       0.87      0.87      0.87       444
# weighted avg       0.87      0.87      0.87       444

# %%
AD=AdaBoostClassifier()

AD.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
predAD=AD.predict(x_test)

# %%
print(accuracy_score(y_test,predAD))

print(confusion_matrix(y_test,predAD))

print(classification_report(y_test, predAD))
# Out:
# 0.8738738738738738
# [[198  26]
#  [ 30 190]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       224
#            1       0.88      0.86      0.87       220
#
#     accuracy                           0.87       444
#    macro avg       0.87      0.87      0.87       444
# weighted avg       0.87      0.87      0.87       444

# %%
LR=LogisticRegression()

LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predLR=LR.predict(x_test)

# %%
print(accuracy_score(y_test,predLR))

print(confusion_matrix(y_test,predLR))

print(classification_report(y_test,predLR))
# Out:
# 0.5990990990990991
# [[126  98]
#  [ 80 140]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.56      0.59       224
#            1       0.59      0.64      0.61       220
#
#     accuracy                           0.60       444
#    macro avg       0.60      0.60      0.60       444
# weighted avg       0.60      0.60      0.60       444

# %%
RFC= RandomForestClassifier()

RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predRFC=RFC.predict(x_test)

# %%
print(accuracy_score(y_test,predRFC))

print(confusion_matrix(y_test, predRFC))

print(classification_report(y_test,predRFC ))
# Out:
# 0.8828828828828829
# [[199  25]
#  [ 27 193]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88       224
#            1       0.89      0.88      0.88       220
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444

# %%
#AMONG ALL THE MACHINE MODEL USED FOR PRRDICTION, IT IS SHOWN THAT RANDOMFORESTCLASSIFIER GAVE THE HIGHEST ACCURACY OF 88%.
#THERE IS 89% PRECISION THAT MOST OF THE FRAUDULENT CLAIM ARE TRUE WHICH HAVE 444 SUPPORT.

# %%
import joblib

# %%
joblib.dump(RFC,'FRAUD_DETECTION.PKI')
# Out:
# ['FRAUD_DETECTION.PKI']
